# %% [markdown]
# # PPO Training
#
# Logan Wong
#
# law3082

# %%
import os
import numpy as np
import pandas as pd
import random
import pickle
import time
import port_for
import subprocess

# Env
import gymnasium as gym
from gymnasium import spaces
import torch

# Algo
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="6"

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
seed = 316
random.seed(seed)
np.random.seed(seed)

# %%
def convert(seconds):
    seconds = seconds % (24 * 3600)
    hour = seconds // 3600
    seconds %= 3600
    minutes = seconds // 60
    seconds %= 60

    return "%d:%02d:%02d" % (hour, minutes, seconds)

# %% [markdown]
# # Load data

# %%
# train_sequences_idx is a Dictionary
# 6040 keys (User indices, NOT User IDs, 0 to 6039)
# Values: list of movie indices, the first 80% of each user's ratings (all ratings 1-5, not filtered for positivity)
with open('../data/train_sequences_idx.pkl', 'rb') as f:
    train_sequences_idx = pickle.load(f)


# ratings_dict is a Dictionary
# Each key is a tuple (user index, movie index)
# Values are that user's rating for that movie
with open('../data/ratings_dict.pkl', 'rb') as f:
    ratings_dict = pickle.load(f)

# user_embeddings is a 6040 x 100 matrix
user_embeddings = np.load('../data/user_embeddings.npy')

# movie_embeddings is a 3706 x 100 matrix
movie_embeddings = np.load('../data/movie_embeddings.npy')

# %% [markdown]
# # Environment

# %%
class TrainPPORecommendationEnv(gym.Env):
    def __init__(self, 
                 train_sequences_idx,    # dict {user_idx: list of movie indices}
                 ratings_dict,          # dict {(user_idx, movie_idx): rating}
                 user_embeddings,       # numpy array (num_users, k)
                 movie_embeddings,      # numpy array (num_movies, k)
                 n_history=5,           # length of positive history
                 T_max=10):              # max steps per episode
        super().__init__()
        self.user_sequences = train_sequences_idx
        self.ratings = ratings_dict
        self.user_embeddings = user_embeddings
        self.movie_embeddings = movie_embeddings
        self.n_history = n_history
        self.T_max = T_max

        # Embedding dimensions
        self.k = movie_embeddings.shape[1]  # 100

        # Observation space: state vector from DRR-ave (size = 3*k)
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(3*self.k,), dtype=np.float32)
        
        # Action space: continuous vector in [-1, 1]
        self.action_space = spaces.Box(low=-1.0, high=1.0, shape=(self.k,), dtype=np.float32)

        # Create state representation module: Implement DRR-ave using numpy
        # Learnable item weights (initialized to 1)
        self.item_weights = np.ones(n_history)

        # Internal variables
        self.current_user = None
        self.history = None
        self.candidate_items = None
        self.recommended_set = None
        self.step_count = 0

    
    def _get_state(self, user_idx, history_indices):
        """Compute state vector: [u, u⊗g, g] with weighted average of history."""
        # u: user embedding
        u = self.user_embeddings[user_idx]                     # (k,)
        # g: weighted average of history items
        # Apply softmax to item weights to make them sum to 1
        weights = np.exp(self.item_weights) / np.sum(np.exp(self.item_weights))
        hist_embs = self.movie_embeddings[history_indices]      # (n_history, k)
        weighted_avg = np.sum(hist_embs * weights[:, np.newaxis], axis=0)  # (k,)
        # u⊗g element-wise product
        u_g = u * weighted_avg
        # Concatenate: [u, u⊗g, g]
        state = np.concatenate([u, u_g, weighted_avg])  # (3*k,)
        return state.astype(np.float32)

    def reset(self, *, seed=None, options=None):
        """
            Start a new episode for a given user.
            seed is passed in when the PPO model is created: PPO(seed=seed)
            stable‑baselines3 with Gymnasium expects options, so set it as None (but you never use it)
        """
        # Set random seed if provided
        if seed is not None:
            np.random.seed(seed)
        # Randomly select a user
        self.current_user = np.random.choice(list(self.user_sequences.keys()))
        seq = self.user_sequences[self.current_user]
    
        # Get MOST RECENT history: first n_history items (NOT the most recent positively rated movies)
        if len(seq) < self.n_history + 1:
            # Fallback: use whatever we have (but ensure we have enough for step)
            self.history = seq[:self.n_history]
        else:
            self.history = seq[:self.n_history].copy()
        # Get candidate set
        self.candidate_items = set(seq[self.n_history:])

        # Set initial state
        self.recommended_set = set()
        self.step_count = 0    
        state = self._get_state(self.current_user, self.history)
        return state, {}

    def step(self, action):
        """
        action: numpy array (k,) continuous vector.
        """

        # 1. Check that candidates exist
        candidates = list(self.candidate_items - self.recommended_set)
        if not candidates:
            # If no items left, then episode ends
            next_state = self._get_state(self.current_user, self.history)
            return next_state, 0.0, True, False, {}

        # 2. Compute scores for every candidate items (dot product with action)
        # Get embeddings of candidates
        cand_emb = self.movie_embeddings[candidates]   # num_cand x k matrix
        scores = cand_emb @ action                     # (num_cand,); 1 score per candidate

        # 3. Select highest scoring item
        best_idx = np.argmax(scores)
        selected_item = candidates[best_idx]

        # 4. Get reward
        rating = self.ratings.get((self.current_user, selected_item), 0)
        reward = (rating - 3) / 2.0

        # 5. Update state history
        new_history = self.history.copy()
        if reward > 0:   # positive feedback
            new_history = new_history[1:] + [selected_item]  # drop oldest, add new
        # else: keep unchanged

        # 6. Update sets
        self.recommended_set.add(selected_item)
        self.step_count += 1

        # 7. Check if you're done or not
        terminated = (len(self.candidate_items - self.recommended_set) == 0)  # no more items
        truncated = (self.step_count >= self.T_max)                           # max steps reached

        # 8. Next state
        next_state = self._get_state(self.current_user, new_history)
        # Update internal history
        self.history = new_history

        # Optional info
        info = {
            'selected_item': selected_item,
            'rating': rating,
            'reward': reward,
            'step': self.step_count
        }

        # Return according to Gymnasium API: obs, reward, terminated, truncated, info
        return next_state, reward, terminated, truncated, info

# %%
env = TrainPPORecommendationEnv(
    train_sequences_idx=train_sequences_idx,
    ratings_dict=ratings_dict,
    user_embeddings=user_embeddings,
    movie_embeddings=movie_embeddings,
    n_history=5,
    T_max=10
)

# %% [markdown]
# # PPO

# %%
# Load tensorboard
port = port_for.get_port(None)
print(f"Starting TensorBoard on port: {port}")

# Kill existing tensorboard
subprocess.run(["pkill", "-f", "tensorboard"])

# Start tensorboard
subprocess.Popen(["tensorboard", "--logdir", "../results/", "--port", f"{port}", "--host", "0.0.0.0"])

# Wait a moment
time.sleep(3)

# Test connection
import requests
try:
    r = requests.get(f"http://localhost:{port}")
    print(f"ssh -L {port}:localhost:{port} -N law3082@narnia.gccis.rit.edu")
    print(f"TensorBoard is running! Status: {r.status_code}")
    print(f"http://localhost:{port}")
except:
    print("TensorBoard failed to start")
# Out:
# Starting TensorBoard on port: 11279
# TensorFlow installation not found - running with reduced feature set.
#
# NOTE: Using experimental fast data loading logic. To disable, pass
#     "--load_fast=false" and report issues on GitHub. More details:
#     https://github.com/tensorflow/tensorboard/issues/4784
#
# TensorBoard 2.20.0 at http://0.0.0.0:11279/ (Press CTRL+C to quit)
# ssh -L 11279:localhost:11279 -N law3082@narnia.gccis.rit.edu
# TensorBoard is running! Status: 200
# http://localhost:11279

# %%
# Original:
# hp_config = {'learning_rate': 0.0003, 
#        'n_steps': 2048, 
#        'batch_size': 64, 
#        'gamma': 0.99, 
#        'ent_coef': 0.0
#       }

hp_config = {'learning_rate': 0.0001, 
       'n_steps': 1024, 
       'batch_size': 128, 
       'gamma': 0.95, 
       'ent_coef': 0.01
      }

# %%
# Wrap environment in a vectorized wrapper
vec_env = DummyVecEnv([lambda: env])

model_name = "PPO"
tensorboard_save_path = f"../results/{model_name}_TB/"

model = PPO(
    policy='MlpPolicy',
    env=vec_env,
    learning_rate=hp_config['learning_rate'],
    n_steps=hp_config['n_steps'],               # steps per rollout
    batch_size=hp_config['batch_size'],
    n_epochs=10,
    gamma=hp_config['gamma'],
    gae_lambda=0.95,
    clip_range=0.2,
    ent_coef=hp_config['ent_coef'],
    vf_coef=0.5,
    max_grad_norm=0.5,

    tensorboard_log=tensorboard_save_path,
    verbose=1,
    seed=seed,
    device='cpu'
)
# Out:
# Using cpu device

# %%
# Train
total_timesteps = 750_000
# total_timesteps = 1_000_000
# total_timesteps = 2_000_000
# total_timesteps = 500_000
# total_timesteps = 10_000

print("Training started")
start_time = time.time()
model.learn(
    total_timesteps=total_timesteps,
    progress_bar=True,
    log_interval=1  # this isn't a boolean, it's saying how often to log info
)
end_time = time.time()
print("Training done")

# Save model
version_number = 3
model.save(f"../models/PPO_Ver_{version_number}_{total_timesteps}")
# Out:
# Training started
# Logging to ../results/PPO_TB/PPO_8
# Output()
# -----------------------------
# | time/              |      |
# |    fps             | 1274 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 1024 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 767         |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 2048        |
# | train/                  |             |
# |    approx_kl            | 0.020061476 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -142        |
# |    explained_variance   | 0.117       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.639      |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0771     |
# |    std                  | 1           |
# |    value_loss           | 2.4         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 643        |
# |    iterations           | 3          |
# |    time_elapsed         | 4          |
# |    total_timesteps      | 3072       |
# | train/                  |            |
# |    approx_kl            | 0.01999263 |
# |    clip_fraction        | 0.196      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -142       |
# |    explained_variance   | 0.0734     |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.289     |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0742    |
# |    std                  | 1          |
# |    value_loss           | 2.65       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 601        |
# |    iterations           | 4          |
# |    time_elapsed         | 6          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.01687057 |
# |    clip_fraction        | 0.156      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -142       |
# |    explained_variance   | 0.175      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.507     |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0651    |
# |    std                  | 1          |
# |    value_loss           | 2.35       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 592         |
# |    iterations           | 5           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.018250596 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -142        |
# |    explained_variance   | 0.136       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.432      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0702     |
# |    std                  | 1           |
# |    value_loss           | 2.56        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 571         |
# |    iterations           | 6           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.019245978 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -142        |
# |    explained_variance   | 0.294       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.842      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0741     |
# |    std                  | 1           |
# |    value_loss           | 1.94        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 564         |
# |    iterations           | 7           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.020021837 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -142        |
# |    explained_variance   | 0.249       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.841      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0759     |
# |    std                  | 1           |
# |    value_loss           | 1.52        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 551         |
# |    iterations           | 8           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.019256556 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -142        |
# |    explained_variance   | 0.217       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.731      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0744     |
# |    std                  | 1.01        |
# |    value_loss           | 1.8         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 540         |
# |    iterations           | 9           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.019997455 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -142        |
# |    explained_variance   | 0.346       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.583      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0791     |
# |    std                  | 1.01        |
# |    value_loss           | 2.19        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 520         |
# |    iterations           | 10          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.018362205 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -143        |
# |    explained_variance   | 0.405       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.562      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0769     |
# |    std                  | 1.01        |
# |    value_loss           | 2.1         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 507        |
# |    iterations           | 11         |
# |    time_elapsed         | 22         |
# |    total_timesteps      | 11264      |
# | train/                  |            |
# |    approx_kl            | 0.01828645 |
# |    clip_fraction        | 0.174      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -143       |
# |    explained_variance   | 0.415      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.856     |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.0736    |
# |    std                  | 1.01       |
# |    value_loss           | 1.87       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 498         |
# |    iterations           | 12          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.020194825 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -143        |
# |    explained_variance   | 0.508       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.98       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0791     |
# |    std                  | 1.01        |
# |    value_loss           | 1.78        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 503        |
# |    iterations           | 13         |
# |    time_elapsed         | 26         |
# |    total_timesteps      | 13312      |
# | train/                  |            |
# |    approx_kl            | 0.01929985 |
# |    clip_fraction        | 0.192      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -143       |
# |    explained_variance   | 0.419      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.594     |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.079     |
# |    std                  | 1.01       |
# |    value_loss           | 2.09       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 502         |
# |    iterations           | 14          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.019652367 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -143        |
# |    explained_variance   | 0.497       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.926      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0772     |
# |    std                  | 1.01        |
# |    value_loss           | 1.78        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 506         |
# |    iterations           | 15          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.022553757 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -143        |
# |    explained_variance   | 0.577       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -1.11       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0857     |
# |    std                  | 1.01        |
# |    value_loss           | 1.26        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 509         |
# |    iterations           | 16          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.020716045 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -143        |
# |    explained_variance   | 0.373       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.89       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0775     |
# |    std                  | 1.01        |
# |    value_loss           | 1.75        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 510         |
# |    iterations           | 17          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 17408       |
# | train/                  |             |
# |    approx_kl            | 0.020444872 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -143        |
# |    explained_variance   | 0.478       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.464      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.078      |
# |    std                  | 1.01        |
# |    value_loss           | 2.2         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 505         |
# |    iterations           | 18          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.021357361 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -143        |
# |    explained_variance   | 0.4         |
# |    learning_rate        | 0.0001      |
# |    loss                 | -1.01       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0794     |
# |    std                  | 1.01        |
# |    value_loss           | 1.7         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 506         |
# |    iterations           | 19          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 19456       |
# | train/                  |             |
# |    approx_kl            | 0.021007381 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -143        |
# |    explained_variance   | 0.583       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.946      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0801     |
# |    std                  | 1.01        |
# |    value_loss           | 1.29        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 503         |
# |    iterations           | 20          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.021316802 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -143        |
# |    explained_variance   | 0.572       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.937      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0799     |
# |    std                  | 1.01        |
# |    value_loss           | 1.58        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 498         |
# |    iterations           | 21          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 21504       |
# | train/                  |             |
# |    approx_kl            | 0.019715685 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -143        |
# |    explained_variance   | 0.656       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.94       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0803     |
# |    std                  | 1.02        |
# |    value_loss           | 1.58        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 492         |
# |    iterations           | 22          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.020850027 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -143        |
# |    explained_variance   | 0.629       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.92       |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0809     |
# |    std                  | 1.02        |
# |    value_loss           | 2.06        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 490        |
# |    iterations           | 23         |
# |    time_elapsed         | 48         |
# |    total_timesteps      | 23552      |
# | train/                  |            |
# |    approx_kl            | 0.02026327 |
# |    clip_fraction        | 0.194      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -143       |
# |    explained_variance   | 0.547      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.871     |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.0784    |
# |    std                  | 1.02       |
# |    value_loss           | 1.86       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 485        |
# |    iterations           | 24         |
# |    time_elapsed         | 50         |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.02118944 |
# |    clip_fraction        | 0.205      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -144       |
# |    explained_variance   | 0.559      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.775     |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.0813    |
# |    std                  | 1.02       |
# |    value_loss           | 1.87       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 481         |
# |    iterations           | 25          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.018897947 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -144        |
# |    explained_variance   | 0.654       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.991      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0773     |
# |    std                  | 1.02        |
# |    value_loss           | 1.68        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 477        |
# |    iterations           | 26         |
# |    time_elapsed         | 55         |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.01965851 |
# |    clip_fraction        | 0.189      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -144       |
# |    explained_variance   | 0.649      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.806     |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.0766    |
# |    std                  | 1.02       |
# |    value_loss           | 2.14       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 474         |
# |    iterations           | 27          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 27648       |
# | train/                  |             |
# |    approx_kl            | 0.020215018 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -144        |
# |    explained_variance   | 0.715       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -1.05       |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0797     |
# |    std                  | 1.02        |
# |    value_loss           | 1.9         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 470         |
# |    iterations           | 28          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.020129614 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -144        |
# |    explained_variance   | 0.677       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.991      |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0795     |
# |    std                  | 1.02        |
# |    value_loss           | 1.56        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 466         |
# |    iterations           | 29          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 29696       |
# | train/                  |             |
# |    approx_kl            | 0.021172669 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -144        |
# |    explained_variance   | 0.672       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -1.04       |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0801     |
# |    std                  | 1.02        |
# |    value_loss           | 1.83        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 465         |
# |    iterations           | 30          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.020891758 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -144        |
# |    explained_variance   | 0.715       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.905      |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0771     |
# |    std                  | 1.02        |
# |    value_loss           | 1.81        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 461         |
# |    iterations           | 31          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 31744       |
# | train/                  |             |
# |    approx_kl            | 0.021245163 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -144        |
# |    explained_variance   | 0.757       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -1.07       |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0807     |
# |    std                  | 1.02        |
# |    value_loss           | 1.66        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 459        |
# |    iterations           | 32         |
# |    time_elapsed         | 71         |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.02070506 |
# |    clip_fraction        | 0.207      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -144       |
# |    explained_variance   | 0.717      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -1.04      |
# |    n_updates            | 310        |
# |    policy_gradient_loss | -0.08      |
# |    std                  | 1.02       |
# |    value_loss           | 1.62       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 457         |
# |    iterations           | 33          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 33792       |
# | train/                  |             |
# |    approx_kl            | 0.020827271 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -144        |
# |    explained_variance   | 0.71        |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.898      |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0786     |
# |    std                  | 1.02        |
# |    value_loss           | 1.68        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 455        |
# |    iterations           | 34         |
# |    time_elapsed         | 76         |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.01965269 |
# |    clip_fraction        | 0.189      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -144       |
# |    explained_variance   | 0.676      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.798     |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.0784    |
# |    std                  | 1.02       |
# |    value_loss           | 2.2        |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 454        |
# |    iterations           | 35         |
# |    time_elapsed         | 78         |
# |    total_timesteps      | 35840      |
# | train/                  |            |
# |    approx_kl            | 0.01992371 |
# |    clip_fraction        | 0.194      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -144       |
# |    explained_variance   | 0.696      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.876     |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.0796    |
# |    std                  | 1.02       |
# |    value_loss           | 1.97       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 453         |
# |    iterations           | 36          |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.020619135 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -144        |
# |    explained_variance   | 0.718       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.915      |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0764     |
# |    std                  | 1.02        |
# |    value_loss           | 2.05        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 455         |
# |    iterations           | 37          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 37888       |
# | train/                  |             |
# |    approx_kl            | 0.021047777 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -144        |
# |    explained_variance   | 0.651       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.978      |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0803     |
# |    std                  | 1.03        |
# |    value_loss           | 1.7         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 457         |
# |    iterations           | 38          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.021257158 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -144        |
# |    explained_variance   | 0.694       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.962      |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0823     |
# |    std                  | 1.03        |
# |    value_loss           | 1.81        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 458         |
# |    iterations           | 39          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 39936       |
# | train/                  |             |
# |    approx_kl            | 0.020552354 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -145        |
# |    explained_variance   | 0.706       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.86       |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0776     |
# |    std                  | 1.03        |
# |    value_loss           | 1.93        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 460         |
# |    iterations           | 40          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.021589845 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -145        |
# |    explained_variance   | 0.645       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.917      |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0823     |
# |    std                  | 1.03        |
# |    value_loss           | 1.72        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 461        |
# |    iterations           | 41         |
# |    time_elapsed         | 90         |
# |    total_timesteps      | 41984      |
# | train/                  |            |
# |    approx_kl            | 0.02330588 |
# |    clip_fraction        | 0.235      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -145       |
# |    explained_variance   | 0.761      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -1.11      |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.0854    |
# |    std                  | 1.03       |
# |    value_loss           | 1.38       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 461         |
# |    iterations           | 42          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.021814108 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -145        |
# |    explained_variance   | 0.693       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -1.04       |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0802     |
# |    std                  | 1.03        |
# |    value_loss           | 1.65        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 462         |
# |    iterations           | 43          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 44032       |
# | train/                  |             |
# |    approx_kl            | 0.022756413 |
# |    clip_fraction        | 0.232       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -145        |
# |    explained_variance   | 0.758       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -1.01       |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0837     |
# |    std                  | 1.03        |
# |    value_loss           | 1.56        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 464         |
# |    iterations           | 44          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.021021236 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -145        |
# |    explained_variance   | 0.768       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.943      |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0814     |
# |    std                  | 1.03        |
# |    value_loss           | 1.72        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 466        |
# |    iterations           | 45         |
# |    time_elapsed         | 98         |
# |    total_timesteps      | 46080      |
# | train/                  |            |
# |    approx_kl            | 0.02250135 |
# |    clip_fraction        | 0.223      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -145       |
# |    explained_variance   | 0.799      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -1.13      |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.0838    |
# |    std                  | 1.03       |
# |    value_loss           | 1.64       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 468         |
# |    iterations           | 46          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.021131877 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -145        |
# |    explained_variance   | 0.809       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -1.14       |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0779     |
# |    std                  | 1.03        |
# |    value_loss           | 1.48        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 469         |
# |    iterations           | 47          |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 48128       |
# | train/                  |             |
# |    approx_kl            | 0.022129308 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -145        |
# |    explained_variance   | 0.797       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -1.01       |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0827     |
# |    std                  | 1.03        |
# |    value_loss           | 1.53        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 468         |
# |    iterations           | 48          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.021940207 |
# |    clip_fraction        | 0.221       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -145        |
# |    explained_variance   | 0.746       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.97       |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0824     |
# |    std                  | 1.03        |
# |    value_loss           | 1.84        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 466         |
# |    iterations           | 49          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 50176       |
# | train/                  |             |
# |    approx_kl            | 0.020245716 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -145        |
# |    explained_variance   | 0.76        |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.803      |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0811     |
# |    std                  | 1.03        |
# |    value_loss           | 2.01        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 466         |
# |    iterations           | 50          |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.021655675 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -145        |
# |    explained_variance   | 0.707       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.997      |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.079      |
# |    std                  | 1.04        |
# |    value_loss           | 1.71        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 466        |
# |    iterations           | 51         |
# |    time_elapsed         | 111        |
# |    total_timesteps      | 52224      |
# | train/                  |            |
# |    approx_kl            | 0.02115632 |
# |    clip_fraction        | 0.204      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -145       |
# |    explained_variance   | 0.626      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.94      |
# |    n_updates            | 500        |
# |    policy_gradient_loss | -0.0812    |
# |    std                  | 1.04       |
# |    value_loss           | 1.87       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 468         |
# |    iterations           | 52          |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.021753706 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -145        |
# |    explained_variance   | 0.719       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.837      |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0817     |
# |    std                  | 1.04        |
# |    value_loss           | 1.8         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 469         |
# |    iterations           | 53          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 54272       |
# | train/                  |             |
# |    approx_kl            | 0.024706367 |
# |    clip_fraction        | 0.247       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -146        |
# |    explained_variance   | 0.727       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.897      |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0874     |
# |    std                  | 1.04        |
# |    value_loss           | 1.45        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 470         |
# |    iterations           | 54          |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.022537336 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -146        |
# |    explained_variance   | 0.83        |
# |    learning_rate        | 0.0001      |
# |    loss                 | -1.03       |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.0833     |
# |    std                  | 1.04        |
# |    value_loss           | 1.71        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 470         |
# |    iterations           | 55          |
# |    time_elapsed         | 119         |
# |    total_timesteps      | 56320       |
# | train/                  |             |
# |    approx_kl            | 0.020365063 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -146        |
# |    explained_variance   | 0.682       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.893      |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.0788     |
# |    std                  | 1.04        |
# |    value_loss           | 2.07        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 471         |
# |    iterations           | 56          |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.023051169 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -146        |
# |    explained_variance   | 0.792       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -1.17       |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.0844     |
# |    std                  | 1.04        |
# |    value_loss           | 1.38        |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 472       |
# |    iterations           | 57        |
# |    time_elapsed         | 123       |
# |    total_timesteps      | 58368     |
# | train/                  |           |
# |    approx_kl            | 0.0218071 |
# |    clip_fraction        | 0.23      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -146      |
# |    explained_variance   | 0.753     |
# |    learning_rate        | 0.0001    |
# |    loss                 | -1.03     |
# |    n_updates            | 560       |
# |    policy_gradient_loss | -0.0824   |
# |    std                  | 1.04      |
# |    value_loss           | 2         |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 474        |
# |    iterations           | 58         |
# |    time_elapsed         | 125        |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.02380648 |
# |    clip_fraction        | 0.24       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -146       |
# |    explained_variance   | 0.744      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -1.05      |
# |    n_updates            | 570        |
# |    policy_gradient_loss | -0.0844    |
# |    std                  | 1.04       |
# |    value_loss           | 1.49       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 475        |
# |    iterations           | 59         |
# |    time_elapsed         | 127        |
# |    total_timesteps      | 60416      |
# | train/                  |            |
# |    approx_kl            | 0.02325318 |
# |    clip_fraction        | 0.25       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -146       |
# |    explained_variance   | 0.694      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -1.1       |
# |    n_updates            | 580        |
# |    policy_gradient_loss | -0.0867    |
# |    std                  | 1.04       |
# |    value_loss           | 1.65       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 472         |
# |    iterations           | 60          |
# |    time_elapsed         | 129         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.022819843 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -146        |
# |    explained_variance   | 0.784       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -1.04       |
# |    n_updates            | 590         |
# |    policy_gradient_loss | -0.0855     |
# |    std                  | 1.04        |
# |    value_loss           | 1.36        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 472        |
# |    iterations           | 61         |
# |    time_elapsed         | 132        |
# |    total_timesteps      | 62464      |
# | train/                  |            |
# |    approx_kl            | 0.02178101 |
# |    clip_fraction        | 0.218      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -146       |
# |    explained_variance   | 0.773      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -1.14      |
# |    n_updates            | 600        |
# |    policy_gradient_loss | -0.0817    |
# |    std                  | 1.04       |
# |    value_loss           | 1.65       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 469         |
# |    iterations           | 62          |
# ...
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 441        |
# |    iterations           | 713        |
# |    time_elapsed         | 1655       |
# |    total_timesteps      | 730112     |
# | train/                  |            |
# |    approx_kl            | 0.02402763 |
# |    clip_fraction        | 0.268      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -198       |
# |    explained_variance   | 0.952      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -1.94      |
# |    n_updates            | 7120       |
# |    policy_gradient_loss | -0.0853    |
# |    std                  | 1.75       |
# |    value_loss           | 0.541      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 441         |
# |    iterations           | 714         |
# |    time_elapsed         | 1657        |
# |    total_timesteps      | 731136      |
# | train/                  |             |
# |    approx_kl            | 0.027102884 |
# |    clip_fraction        | 0.275       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -198        |
# |    explained_variance   | 0.934       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -1.93       |
# |    n_updates            | 7130        |
# |    policy_gradient_loss | -0.0842     |
# |    std                  | 1.75        |
# |    value_loss           | 0.62        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 441        |
# |    iterations           | 715        |
# |    time_elapsed         | 1659       |
# |    total_timesteps      | 732160     |
# | train/                  |            |
# |    approx_kl            | 0.02399141 |
# |    clip_fraction        | 0.263      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -198       |
# |    explained_variance   | 0.913      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -1.94      |
# |    n_updates            | 7140       |
# |    policy_gradient_loss | -0.0847    |
# |    std                  | 1.75       |
# |    value_loss           | 0.704      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 441         |
# |    iterations           | 716         |
# |    time_elapsed         | 1662        |
# |    total_timesteps      | 733184      |
# | train/                  |             |
# |    approx_kl            | 0.024356894 |
# |    clip_fraction        | 0.269       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -198        |
# |    explained_variance   | 0.946       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -1.92       |
# |    n_updates            | 7150        |
# |    policy_gradient_loss | -0.0858     |
# |    std                  | 1.76        |
# |    value_loss           | 0.614       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 440         |
# |    iterations           | 717         |
# |    time_elapsed         | 1664        |
# |    total_timesteps      | 734208      |
# | train/                  |             |
# |    approx_kl            | 0.025415707 |
# |    clip_fraction        | 0.258       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -198        |
# |    explained_variance   | 0.922       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -1.91       |
# |    n_updates            | 7160        |
# |    policy_gradient_loss | -0.083      |
# |    std                  | 1.76        |
# |    value_loss           | 0.642       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 440         |
# |    iterations           | 719         |
# |    time_elapsed         | 1669        |
# |    total_timesteps      | 736256      |
# | train/                  |             |
# |    approx_kl            | 0.025297906 |
# |    clip_fraction        | 0.26        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -198        |
# |    explained_variance   | 0.923       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -1.96       |
# |    n_updates            | 7180        |
# |    policy_gradient_loss | -0.0854     |
# |    std                  | 1.76        |
# |    value_loss           | 0.576       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 441         |
# |    iterations           | 720         |
# |    time_elapsed         | 1671        |
# |    total_timesteps      | 737280      |
# | train/                  |             |
# |    approx_kl            | 0.024933405 |
# |    clip_fraction        | 0.26        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -198        |
# |    explained_variance   | 0.909       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -1.92       |
# |    n_updates            | 7190        |
# |    policy_gradient_loss | -0.0865     |
# |    std                  | 1.76        |
# |    value_loss           | 0.652       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 441         |
# |    iterations           | 721         |
# |    time_elapsed         | 1673        |
# |    total_timesteps      | 738304      |
# | train/                  |             |
# |    approx_kl            | 0.022825927 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -198        |
# |    explained_variance   | 0.907       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -1.86       |
# |    n_updates            | 7200        |
# |    policy_gradient_loss | -0.0825     |
# |    std                  | 1.76        |
# |    value_loss           | 0.663       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 441         |
# |    iterations           | 722         |
# |    time_elapsed         | 1675        |
# |    total_timesteps      | 739328      |
# | train/                  |             |
# |    approx_kl            | 0.024809621 |
# |    clip_fraction        | 0.257       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -198        |
# |    explained_variance   | 0.908       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -1.94       |
# |    n_updates            | 7210        |
# |    policy_gradient_loss | -0.085      |
# |    std                  | 1.76        |
# |    value_loss           | 0.636       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 441         |
# |    iterations           | 723         |
# |    time_elapsed         | 1678        |
# |    total_timesteps      | 740352      |
# | train/                  |             |
# |    approx_kl            | 0.023921158 |
# |    clip_fraction        | 0.241       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -198        |
# |    explained_variance   | 0.92        |
# |    learning_rate        | 0.0001      |
# |    loss                 | -1.93       |
# |    n_updates            | 7220        |
# |    policy_gradient_loss | -0.0819     |
# |    std                  | 1.76        |
# |    value_loss           | 0.621       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 441        |
# |    iterations           | 724        |
# |    time_elapsed         | 1680       |
# |    total_timesteps      | 741376     |
# | train/                  |            |
# |    approx_kl            | 0.02477525 |
# |    clip_fraction        | 0.256      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -198       |
# |    explained_variance   | 0.943      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -1.92      |
# |    n_updates            | 7230       |
# |    policy_gradient_loss | -0.0818    |
# |    std                  | 1.77       |
# |    value_loss           | 0.648      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 441         |
# |    iterations           | 725         |
# |    time_elapsed         | 1682        |
# |    total_timesteps      | 742400      |
# | train/                  |             |
# |    approx_kl            | 0.024043934 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -199        |
# |    explained_variance   | 0.925       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -1.91       |
# |    n_updates            | 7240        |
# |    policy_gradient_loss | -0.0814     |
# |    std                  | 1.77        |
# |    value_loss           | 0.69        |
# -----------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 441      |
# |    iterations           | 726      |
# |    time_elapsed         | 1685     |
# |    total_timesteps      | 743424   |
# | train/                  |          |
# |    approx_kl            | 0.025883 |
# |    clip_fraction        | 0.271    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -199     |
# |    explained_variance   | 0.927    |
# |    learning_rate        | 0.0001   |
# |    loss                 | -1.88    |
# |    n_updates            | 7250     |
# |    policy_gradient_loss | -0.0852  |
# |    std                  | 1.77     |
# |    value_loss           | 0.657    |
# --------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 441         |
# |    iterations           | 727         |
# |    time_elapsed         | 1687        |
# |    total_timesteps      | 744448      |
# | train/                  |             |
# |    approx_kl            | 0.021707784 |
# |    clip_fraction        | 0.228       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -199        |
# |    explained_variance   | 0.931       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -1.86       |
# |    n_updates            | 7260        |
# |    policy_gradient_loss | -0.0758     |
# |    std                  | 1.77        |
# |    value_loss           | 0.697       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 441         |
# |    iterations           | 728         |
# |    time_elapsed         | 1690        |
# |    total_timesteps      | 745472      |
# | train/                  |             |
# |    approx_kl            | 0.024141539 |
# |    clip_fraction        | 0.261       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -199        |
# |    explained_variance   | 0.927       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -1.84       |
# |    n_updates            | 7270        |
# |    policy_gradient_loss | -0.0847     |
# |    std                  | 1.77        |
# |    value_loss           | 0.668       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 441        |
# |    iterations           | 729        |
# |    time_elapsed         | 1692       |
# |    total_timesteps      | 746496     |
# | train/                  |            |
# |    approx_kl            | 0.02323483 |
# |    clip_fraction        | 0.214      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -199       |
# |    explained_variance   | 0.882      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -1.85      |
# |    n_updates            | 7280       |
# |    policy_gradient_loss | -0.0774    |
# |    std                  | 1.77       |
# |    value_loss           | 0.761      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 441         |
# |    iterations           | 730         |
# |    time_elapsed         | 1694        |
# |    total_timesteps      | 747520      |
# | train/                  |             |
# |    approx_kl            | 0.024872378 |
# |    clip_fraction        | 0.259       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -199        |
# |    explained_variance   | 0.927       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -1.92       |
# |    n_updates            | 7290        |
# |    policy_gradient_loss | -0.0832     |
# |    std                  | 1.77        |
# |    value_loss           | 0.664       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 441         |
# |    iterations           | 731         |
# |    time_elapsed         | 1696        |
# |    total_timesteps      | 748544      |
# | train/                  |             |
# |    approx_kl            | 0.025234692 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -199        |
# |    explained_variance   | 0.948       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -1.9        |
# |    n_updates            | 7300        |
# |    policy_gradient_loss | -0.0841     |
# |    std                  | 1.77        |
# |    value_loss           | 0.665       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 441         |
# |    iterations           | 732         |
# |    time_elapsed         | 1699        |
# |    total_timesteps      | 749568      |
# | train/                  |             |
# |    approx_kl            | 0.024159167 |
# |    clip_fraction        | 0.244       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -199        |
# |    explained_variance   | 0.94        |
# |    learning_rate        | 0.0001      |
# |    loss                 | -1.95       |
# |    n_updates            | 7310        |
# |    policy_gradient_loss | -0.0825     |
# |    std                  | 1.77        |
# |    value_loss           | 0.64        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 440         |
# |    iterations           | 733         |
# |    time_elapsed         | 1702        |
# |    total_timesteps      | 750592      |
# | train/                  |             |
# |    approx_kl            | 0.025942482 |
# |    clip_fraction        | 0.257       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -199        |
# |    explained_variance   | 0.948       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -1.91       |
# |    n_updates            | 7320        |
# |    policy_gradient_loss | -0.0845     |
# |    std                  | 1.78        |
# |    value_loss           | 0.627       |
# -----------------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Training done

# %%
# Calculate run time
training_duration = end_time - start_time
time_in_minutes_and_seconds = convert(training_duration)
print(f"Time taken: {time_in_minutes_and_seconds}")

# Time taken for 500K steps: 0:21:25
# Time taken for 2M steps: 1:18:11
# Time taken for 1M steps: 0:38:01
# Time taken for 750K steps: 0:28:23
# Out:
# Time taken: 0:28:23
