# %% [markdown]
# # DDPG LIME Explanations

# %%
# !pip install lime

# %%
import os
import numpy as np
import pickle
import random
import pandas as pd
import copy
import time

import torch
import torch.nn as nn
import torch.nn.functional as F

# LIME
import lime
from lime import lime_tabular
from lime.lime_tabular import LimeTabularExplainer

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="6"

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
seed = 316
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

# %%
def convert(seconds):
    seconds = seconds % (24 * 3600)
    hour = seconds // 3600
    seconds %= 3600
    minutes = seconds // 60
    seconds %= 60

    return "%d:%02d:%02d" % (hour, minutes, seconds)

# %% [markdown]
# # Load Data

# %%
# with open('../data/user_sequences.pkl', 'rb') as f:
#     user_sequences = pickle.load(f)
with open('../data/train_sequences.pkl', 'rb') as f:
    train_sequences = pickle.load(f)
with open('../data/test_sequences.pkl', 'rb') as f:
    test_sequences = pickle.load(f)

# train_sequences and test_sequences are dictionaries like user_sequences
# Keys: UserIDs (ints)
# Values: list of tuples, each tuple is (movieID, rating)

# %%
with open('../data/user2idx.pkl', 'rb') as f:
    user2idx = pickle.load(f)
# with open('../data/idx2user.pkl', 'rb') as f:
#     idx2user = pickle.load(f)
# with open('../data/movie2idx.pkl', 'rb') as f:
    # movie2idx = pickle.load(f)
with open('../data/idx2movie.pkl', 'rb') as f:
    idx2movie = pickle.load(f)

# %%
# with open('../data/user_sequences_idx.pkl', 'rb') as f:
#     user_sequences_idx = pickle.load(f)

with open('../data/train_sequences_idx.pkl', 'rb') as f:
    train_sequences_idx = pickle.load(f)

with open('../data/test_sequences_idx.pkl', 'rb') as f:
    test_sequences_idx = pickle.load(f)

# %%
user_embeddings = np.load('../data/user_embeddings.npy')
movie_embeddings = np.load('../data/movie_embeddings.npy')

print(f"User embeddings: {user_embeddings.shape}") # should be 6040
print(f"Movie embeddings: {movie_embeddings.shape}") # should be 3706
# Out:
# User embeddings: (6040, 100) (should match 6040 users)
# Movie embeddings: (3706, 100) (should match 3706 movies)

# %%
pmf_raw_data = pd.read_csv("../data/movielens_1M_pmf_raw_data.csv")
print(f"Loaded {len(pmf_raw_data)} ratings")
# Out:
# Loaded 1000209 ratings

# %%
# Load the ratings dictionary
with open('../data/ratings_dict.pkl', 'rb') as f:
    ratings_dict = pickle.load(f)

print(f"Loaded {len(ratings_dict)} entries into ratings_dict")
# Out:
# Loaded 1000209 entries into ratings_dict

# %%
# type(ratings_dict)
# list(ratings_dict.keys())

# %%
# File paths
DATA_DIR = "../data/ml-1m"
RATINGS_FILE = os.path.join(DATA_DIR, "ratings.dat")
USERS_FILE = os.path.join(DATA_DIR, "users.dat")
MOVIES_FILE = os.path.join(DATA_DIR, "movies.dat")

# Column names
ratings_cols = ['user_id', 'movie_id', 'rating', 'timestamp']
users_cols = ['user_id', 'gender', 'age', 'occupation', 'zip_code']
movies_cols = ['movie_id', 'title', 'genres']

# Load data
ratings = pd.read_csv(RATINGS_FILE, sep='::', engine='python', names=ratings_cols, encoding='latin-1')
users = pd.read_csv(USERS_FILE, sep='::', engine='python', names=users_cols, encoding='latin-1')
movies = pd.read_csv(MOVIES_FILE, sep='::', engine='python', names=movies_cols, encoding='latin-1')

# %%
# Dictionary that maps MovieID to Title for Quick Lookup
with open('../data/movie_id_to_title.pkl', 'rb') as f:
    movie_id_to_title = pickle.load(f)

# %% [markdown]
# # Load Model

# %%
class Actor(nn.Module):
    """
    Randomly initialize the Actor πθ
    Thus assuming standard implementation.
    
    maps: state -> action
    From paper: "By two ReLU layers and one Tanh layer, the state representation s 
    is transformed into an action a = π_θ(s)"
    """
    def __init__(self, state_dim, action_dim=100, hidden_dim=256):
        super().__init__()
        self.fc1 = nn.Linear(state_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, action_dim)
        
        # Initialize weights
        nn.init.xavier_uniform_(self.fc1.weight)
        nn.init.xavier_uniform_(self.fc2.weight)
        nn.init.xavier_uniform_(self.fc3.weight)
        
    def forward(self, state):
        x = F.relu(self.fc1(state))
        x = F.relu(self.fc2(x))
        # Tanh maps action to [-1, 1]
        action = torch.tanh(self.fc3(x))
        return action

# %%
# Load Actor and Critic models
version_number = 2

state_dim = 300
actor = Actor(state_dim)
actor = actor.to(device)
# Load the weights into that architecture
actor.load_state_dict(torch.load(f'../models/drr_actor_weights_{version_number}.pth'))
actor.eval()
# Out:
# /tmp/ipykernel_4057057/187023785.py:8: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   actor.load_state_dict(torch.load(f'../models/drr_actor_weights_{version_number}.pth'))
# Actor(
#   (fc1): Linear(in_features=300, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=100, bias=True)
# )

# %% [markdown]
# # Create LIME functions

# %%
# a Wrapper that perturbs the HISTORY items
class HistoryExplainerWrapper:
    def __init__(self, actor, user_idx, history_indices, movie_embeddings, user_embeddings, target_item_idx, device):
        self.actor = actor
        self.u = user_embeddings[user_idx]
        self.history_indices = history_indices
        self.movie_embeddings = movie_embeddings
        self.target_emb = torch.FloatTensor(movie_embeddings[target_item_idx]).to(device)
        self.device = device

    def predict(self, masks):
        """
        masks: (N, 5) binary array. 1 means "keep movie in history", 0 means "remove it".
        """
        scores = []
        for mask in masks:
            # print(f"MASK: {mask}")
            # Filter history based on mask (if all 0, use a dummy)
            active_indices = [self.history_indices[i] for i in range(len(mask)) if mask[i] > 0.5]
            if not active_indices: active_indices = [self.history_indices[0]] 
            
            # Recompute 'g' (the DRR-ave history average)
            g = np.mean(self.movie_embeddings[active_indices], axis=0)
            u_g = self.u * g
            state = np.concatenate([self.u, u_g, g])
            
            # Get Actor Score
            with torch.no_grad():
                state_t = torch.FloatTensor(state).to(self.device).unsqueeze(0)
                action = self.actor(state_t).squeeze(0)
                score = torch.dot(action, self.target_emb).item()
            scores.append(score)
        return np.array(scores)

# %%
def clean_movie_title(text):
    # 1. Split by '=' and take the first part
    step1 = text.split('=')[0]
    # 2. Split that result by '>' and take the first part
    step2 = step1.split('>')[0]
    
    final_title = step2.strip()
    return final_title

# %%
def get_influence_label(weight):
    # Check if the weight is a positive number
    if weight > 0:
        return "+"
    else:
        # This handles both negative numbers AND exactly 0
        return "-"

# %%
# Load the saved trajectory
with open('../results/baseline_session_trajectories.pkl', 'rb') as f:
    sessions = pickle.load(f)

# %%
users_to_explain = [1, 3, 40, 67, 316]

for user_id in users_to_explain:
    session = sessions[user_id]
    print(f"\n{'='*60}")
    print(f"USER {user_id}")
    for step in session['steps']:
        print(f"{step['step']}: {step['recommended_movie_title']} (rating {step['rating']})")

    for step in session['steps']:
        print(f"\nStep {step['step']}: Recommended {step['recommended_movie_title']} (rating {step['rating']})")
        # Get history at this moment
        history_at_time = step['history_at_time']
        history_titles = [movie_id_to_title[idx2movie[idx]] for idx in history_at_time]
        history_ratings = [ratings_dict.get((user2idx[user_id], idx), 'N/A') for idx in history_at_time]


        # Create LIME explainer
        background = np.random.randint(0, 2, size=(500, len(history_at_time)))
        explainer = LimeTabularExplainer(
            training_data=background,
            feature_names=history_titles,
            categorical_features=list(range(len(history_at_time))),
            mode='regression'
        )
        
        # Create wrapper
        wrapper = HistoryExplainerWrapper(
            actor, 
            user2idx[user_id], 
            history_at_time,
            movie_embeddings, 
            user_embeddings, 
            step['recommended_movie_idx'], 
            device
        )
        
        # Explain
        exp = explainer.explain_instance(
            np.ones(len(history_at_time)),
            wrapper.predict,
            num_features=len(history_at_time)
        )
        
        # Print results
        exp_list = exp.as_list()
        
        # Create title-to-rating mapping BEFORE creating DataFrame
        title_to_rating = {}
        for title, idx in zip(history_titles, history_at_time):
            cleaned = clean_movie_title(title)
            rating = ratings_dict.get((user2idx[user_id], idx), 'N/A')
            title_to_rating[cleaned] = rating
        
        # Now create DataFrame with correct ratings
        df = pd.DataFrame(exp_list, columns=["Movie in History", "Weight"])
        df["Movie in History"] = df["Movie in History"].apply(clean_movie_title)
        df["Rating"] = df["Movie in History"].map(title_to_rating)  # Map using the dictionary
        df["Influence"] = df["Weight"].apply(get_influence_label)
        df["Weight"] = df["Weight"].round(2)
        df = df.sort_values("Weight", ascending=False)
                
        print(df[["Movie in History", "Rating", "Weight", "Influence"]].to_string())
# Out:
# ============================================================
# USER 1
# 1: Tarzan (1999) (rating 3)
# 2: Hercules (1997) (rating 4)
# 3: Toy Story (1995) (rating 5)
# 4: Pocahontas (1995) (rating 5)
# 5: Beauty and the Beast (1991) (rating 5)
# 6: Hunchback of Notre Dame, The (1996) (rating 4)
# 7: Bug's Life, A (1998) (rating 5)
# 8: Mulan (1998) (rating 4)
# 9: Close Shave, A (1995) (rating 3)
# 10: Aladdin (1992) (rating 4)
#
# Step 1: Recommended Tarzan (1999) (rating 3)
#                          Movie in History  Rating  Weight Influence
# 0                          Ponette (1996)     4.0    1.58         +
# 4  Snow White and the Seven Dwarfs (1937)     4.0   -0.09         -
# 3                 Schindler's List (1993)     5.0   -0.19         -
# 2                            Dumbo (1941)     5.0   -0.47         -
# 1           Miracle on 34th Street (1947)     4.0   -0.82         -
#
# Step 2: Recommended Hercules (1997) (rating 4)
#                          Movie in History  Rating  Weight Influence
# 0                          Ponette (1996)     4.0    0.93         +
# 3                            Dumbo (1941)     5.0    0.23         +
# 4                 Schindler's List (1993)     5.0    0.08         +
# 2  Snow White and the Seven Dwarfs (1937)     4.0   -0.39         -
# 1           Miracle on 34th Street (1947)     4.0   -0.62         -
#
# Step 3: Recommended Toy Story (1995) (rating 5)
#                          Movie in History  Rating  Weight Influence
# 0                          Ponette (1996)     4.0    0.64         +
# 3                         Hercules (1997)     4.0    0.27         +
# 4                            Dumbo (1941)     5.0    0.07         +
# 5           Miracle on 34th Street (1947)     4.0   -0.07         -
# 2                 Schindler's List (1993)     5.0   -0.35         -
# 1  Snow White and the Seven Dwarfs (1937)     4.0   -0.40         -
#
# Step 4: Recommended Pocahontas (1995) (rating 5)
#                          Movie in History  Rating  Weight Influence
# 0                          Ponette (1996)     4.0    0.92         +
# 2                        Toy Story (1995)     5.0    0.50         +
# 4                            Dumbo (1941)     5.0    0.19         +
# 6                         Hercules (1997)     4.0   -0.01         -
# 5  Snow White and the Seven Dwarfs (1937)     4.0   -0.07         -
# 3                 Schindler's List (1993)     5.0   -0.45         -
# 1           Miracle on 34th Street (1947)     4.0   -0.60         -
#
# Step 5: Recommended Beauty and the Beast (1991) (rating 5)
#                          Movie in History  Rating  Weight Influence
# 0                       Pocahontas (1995)     5.0    0.56         +
# 2                         Hercules (1997)     4.0    0.22         +
# 6                          Ponette (1996)     4.0    0.05         +
# 7           Miracle on 34th Street (1947)     4.0   -0.04         -
# 4                            Dumbo (1941)     5.0   -0.09         -
# 5  Snow White and the Seven Dwarfs (1937)     4.0   -0.09         -
# 3                        Toy Story (1995)     5.0   -0.15         -
# 1                 Schindler's List (1993)     5.0   -0.27         -
#
# Step 6: Recommended Hunchback of Notre Dame, The (1996) (rating 4)
#                          Movie in History  Rating  Weight Influence
# 0           Miracle on 34th Street (1947)     4.0    0.53         +
# 2                          Ponette (1996)     4.0    0.27         +
# 7                            Dumbo (1941)     5.0    0.03         +
# 8                        Toy Story (1995)     5.0    0.01         +
# 6                       Pocahontas (1995)     5.0   -0.04         -
# 5  Snow White and the Seven Dwarfs (1937)     4.0   -0.08         -
# 4             Beauty and the Beast (1991)     5.0   -0.09         -
# 3                 Schindler's List (1993)     5.0   -0.21         -
# 1                         Hercules (1997)     4.0   -0.29         -
#
# Step 7: Recommended Bug's Life, A (1998) (rating 5)
#                          Movie in History  Rating  Weight Influence
# 1     Hunchback of Notre Dame, The (1996)     4.0    0.20         +
# 2                       Pocahontas (1995)     5.0    0.19         +
# 4                            Dumbo (1941)     5.0    0.15         +
# 8             Beauty and the Beast (1991)     5.0    0.05         +
# 9  Snow White and the Seven Dwarfs (1937)     4.0   -0.00         -
# 7                         Hercules (1997)     4.0   -0.05         -
# 6                        Toy Story (1995)     5.0   -0.11         -
# 5           Miracle on 34th Street (1947)     4.0   -0.12         -
# 3                          Ponette (1996)     4.0   -0.15         -
# 0                 Schindler's List (1993)     5.0   -0.22         -
#
# Step 8: Recommended Mulan (1998) (rating 4)
#                           Movie in History  Rating  Weight Influence
# 0            Miracle on 34th Street (1947)     4.0    0.69         +
# 2                        Pocahontas (1995)     5.0    0.47         +
# 4                           Ponette (1996)     4.0    0.44         +
# 5      Hunchback of Notre Dame, The (1996)     4.0    0.40         +
# 9                             Dumbo (1941)     5.0    0.12         +
# 10                         Hercules (1997)     4.0    0.11         +
# 8                     Bug's Life, A (1998)     5.0   -0.21         -
# 7                         Toy Story (1995)     5.0   -0.35         -
# 6                  Schindler's List (1993)     5.0   -0.36         -
# 3   Snow White and the Seven Dwarfs (1937)     4.0   -0.46         -
# 1              Beauty and the Beast (1991)     5.0   -0.55         -
#
# Step 9: Recommended Close Shave, A (1995) (rating 3)
#                           Movie in History  Rating  Weight Influence
# 0                           Ponette (1996)     4.0    0.50         +
# 1      Hunchback of Notre Dame, The (1996)     4.0    0.38         +
# 7   Snow White and the Seven Dwarfs (1937)     4.0    0.09         +
# 11           Miracle on 34th Street (1947)     4.0    0.02         +
# 10             Beauty and the Beast (1991)     5.0   -0.07         -
# 8                         Toy Story (1995)     5.0   -0.09         -
# 9                             Dumbo (1941)     5.0   -0.09         -
# 6                  Schindler's List (1993)     5.0   -0.12         -
# 5                          Hercules (1997)     4.0   -0.15         -
# 3                     Bug's Life, A (1998)     5.0   -0.18         -
# 4                             Mulan (1998)     4.0   -0.18         -
# 2                        Pocahontas (1995)     5.0   -0.22         -
#
# Step 10: Recommended Aladdin (1992) (rating 4)
#                           Movie in History  Rating  Weight Influence
# 4   Snow White and the Seven Dwarfs (1937)     4.0    0.11         +
# 6      Hunchback of Notre Dame, The (1996)     4.0    0.05         +
# 7                          Hercules (1997)     4.0    0.05         +
# 8              Beauty and the Beast (1991)     5.0    0.04         +
# 9                           Ponette (1996)     4.0    0.04         +
# 10                        Toy Story (1995)     5.0    0.02         +
# 11                       Pocahontas (1995)     5.0   -0.01         -
# 5                  Schindler's List (1993)     5.0   -0.11         -
# 3                             Mulan (1998)     4.0   -0.12         -
# 1                     Bug's Life, A (1998)     5.0   -0.13         -
# 2                             Dumbo (1941)     5.0   -0.13         -
# 0            Miracle on 34th Street (1947)     4.0   -0.25         -
#
# ============================================================
# USER 3
# 1: Full Monty, The (1997) (rating 2)
# 2: Little Mermaid, The (1989) (rating 4)
# 3: Caddyshack (1980) (rating 5)
# 4: Naked Gun: From the Files of Police Squad!, The (1988) (rating 3)
# 5: Stand by Me (1986) (rating 5)
# 6: Back to the Future (1985) (rating 3)
# 7: Happy Gilmore (1996) (rating 4)
# 8: Groundhog Day (1993) (rating 2)
# 9: Bug's Life, A (1998) (rating 5)
# 10: Fish Called Wanda, A (1988) (rating 5)
#
# Step 1: Recommended Full Monty, The (1997) (rating 2)
#                             Movie in History  Rating  Weight Influence
# 0                   Golden Child, The (1986)     4.0    1.46         +
# 3  Butch Cassidy and the Sundance Kid (1969)     5.0    0.09         +
# 4                     Raising Arizona (1987)     4.0    0.06         +
# 2                        Animal House (1978)     4.0   -0.14         -
# 1     Monty Python and the Holy Grail (1974)     5.0   -0.58         -
#
# Step 2: Recommended Little Mermaid, The (1989) (rating 4)
#                             Movie in History  Rating  Weight Influence
# 0  Butch Cassidy and the Sundance Kid (1969)     5.0    0.97         +
# 2                   Golden Child, The (1986)     4.0    0.45         +
# 4                        Animal House (1978)     4.0    0.13         +
# 3                     Raising Arizona (1987)     4.0   -0.15         -
# 1     Monty Python and the Holy Grail (1974)     5.0   -0.73         -
#
# Step 3: Recommended Caddyshack (1980) (rating 5)
#                             Movie in History  Rating  Weight Influence
# 0                 Little Mermaid, The (1989)     4.0    0.90         +
# 3  Butch Cassidy and the Sundance Kid (1969)     5.0    0.33         +
# 4                     Raising Arizona (1987)     4.0    0.30         +
# 5                   Golden Child, The (1986)     4.0    0.09         +
# 2     Monty Python and the Holy Grail (1974)     5.0   -0.41         -
# 1                        Animal House (1978)     4.0   -0.44         -
#
# Step 4: Recommended Naked Gun: From the Files of Police Squad!, The (1988) (rating 3)
#                             Movie in History  Rating  Weight Influence
# 1                   Golden Child, The (1986)     4.0    0.75         +
# 2                 Little Mermaid, The (1989)     4.0    0.53         +
# 3                        Animal House (1978)     4.0    0.44         +
# 5                          Caddyshack (1980)     5.0    0.28         +
# 6  Butch Cassidy and the Sundance Kid (1969)     5.0   -0.09         -
# 4                     Raising Arizona (1987)     4.0   -0.42         -
# 0     Monty Python and the Holy Grail (1974)     5.0   -0.76         -
#
# Step 5: Recommended Stand by Me (1986) (rating 5)
#                             Movie in History  Rating  Weight Influence
# 0                   Golden Child, The (1986)     4.0    1.13         +
# 3                 Little Mermaid, The (1989)     4.0    0.32         +
# 4                          Caddyshack (1980)     5.0    0.17         +
# 6  Butch Cassidy and the Sundance Kid (1969)     5.0   -0.04         -
# 5                        Animal House (1978)     4.0   -0.07         -
# 2     Monty Python and the Holy Grail (1974)     5.0   -0.42         -
# 1                     Raising Arizona (1987)     4.0   -0.67         -
#
# Step 6: Recommended Back to the Future (1985) (rating 3)
#                             Movie in History  Rating  Weight Influence
# 0  Butch Cassidy and the Sundance Kid (1969)     5.0    0.56         +
# 2                          Caddyshack (1980)     5.0    0.30         +
# 3                        Animal House (1978)     4.0    0.22         +
# 6                   Golden Child, The (1986)     4.0    0.07         +
# 7                 Little Mermaid, The (1989)     4.0   -0.04         -
# 5     Monty Python and the Holy Grail (1974)     5.0   -0.11         -
# 4                     Raising Arizona (1987)     4.0   -0.16         -
# 1                         Stand by Me (1986)     5.0   -0.42         -
#
# Step 7: Recommended Happy Gilmore (1996) (rating 4)
#                             Movie in History  Rating  Weight Influence
# 1                   Golden Child, The (1986)     4.0    0.57         +
# 2  Butch Cassidy and the Sundance Kid (1969)     5.0    0.42         +
# 3                 Little Mermaid, The (1989)     4.0    0.36         +
# 6                          Caddyshack (1980)     5.0    0.13         +
# 7                        Animal House (1978)     4.0   -0.05         -
# 5                         Stand by Me (1986)     5.0   -0.15         -
# 4                     Raising Arizona (1987)     4.0   -0.30         -
# 0     Monty Python and the Holy Grail (1974)     5.0   -0.79         -
#
# Step 8: Recommended Groundhog Day (1993) (rating 2)
#                             Movie in History  Rating  Weight Influence
# 2                       Happy Gilmore (1996)     4.0    0.18         +
# 3  Butch Cassidy and the Sundance Kid (1969)     5.0    0.15         +
# 4                 Little Mermaid, The (1989)     4.0    0.12         +
# 5                     Raising Arizona (1987)     4.0    0.11         +
# 6                   Golden Child, The (1986)     4.0    0.05         +
# 7                        Animal House (1978)     4.0    0.03         +
# 8                          Caddyshack (1980)     5.0    0.03         +
# 1                         Stand by Me (1986)     5.0   -0.28         -
# 0     Monty Python and the Holy Grail (1974)     5.0   -0.31         -
#
# Step 9: Recommended Bug's Life, A (1998) (rating 5)
#                             Movie in History  Rating  Weight Influence
# 1                          Caddyshack (1980)     5.0    0.28         +
# 3                   Golden Child, The (1986)     4.0    0.25         +
# 4                 Little Mermaid, The (1989)     4.0    0.18         +
# 5                       Happy Gilmore (1996)     4.0    0.08         +
# 6                        Animal House (1978)     4.0    0.07         +
# 7  Butch Cassidy and the Sundance Kid (1969)     5.0    0.05         +
# 8                     Raising Arizona (1987)     4.0    0.03         +
# 2                         Stand by Me (1986)     5.0   -0.28         -
# 0     Monty Python and the Holy Grail (1974)     5.0   -0.34         -
#
# Step 10: Recommended Fish Called Wanda, A (1988) (rating 5)
#                             Movie in History  Rating  Weight Influence
# 0                   Golden Child, The (1986)     4.0    0.65         +
# 4                       Happy Gilmore (1996)     4.0    0.25         +
# 6                          Caddyshack (1980)     5.0    0.11         +
# 7                        Animal House (1978)     4.0    0.11         +
# 8                 Little Mermaid, The (1989)     4.0    0.08         +
# 9  Butch Cassidy and the Sundance Kid (1969)     5.0    0.02         +
# 5                     Raising Arizona (1987)     4.0   -0.17         -
# 2     Monty Python and the Holy Grail (1974)     5.0   -0.33         -
# 3                       Bug's Life, A (1998)     5.0   -0.33         -
# 1                         Stand by Me (1986)     5.0   -0.40         -
#
# ============================================================
# USER 40
# 1: Pork Chop Hill (1959) (rating 3)
# 2: South Pacific (1958) (rating 3)
# 3: Independence Day (ID4) (1996) (rating 4)
# 4: Fighting Seabees, The (1944) (rating 4)
# 5: Them! (1954) (rating 5)
# 6: Aces: Iron Eagle III (1992) (rating 1)
# 7: Force 10 from Navarone (1978) (rating 2)
# 8: Tora! Tora! Tora! (1970) (rating 3)
# 9: Rambo: First Blood Part II (1985) (rating 2)
# 10: Hot Shots! Part Deux (1993) (rating 4)
#
# Step 1: Recommended Pork Chop Hill (1959) (rating 3)
#                  Movie in History  Rating  Weight Influence
# 0      Farewell to Arms, A (1932)     4.0    1.90         +
# 3                 Lifeboat (1944)     5.0    0.17         +
# 4         Dirty Dozen, The (1967)     4.0    0.10         +
# 2  For Whom the Bell Tolls (1943)     4.0   -0.38         -
# 1   War of the Worlds, The (1953)     4.0   -1.71         -
#
# Step 2: Recommended South Pacific (1958) (rating 3)
#                  Movie in History  Rating  Weight Influence
# 1   War of the Worlds, The (1953)     4.0    0.96         +
# 2         Dirty Dozen, The (1967)     4.0    0.42         +
# 3                 Lifeboat (1944)     5.0    0.40         +
# 4  For Whom the Bell Tolls (1943)     4.0   -0.25         -
# 0      Farewell to Arms, A (1932)     4.0   -1.06         -
#
# Step 3: Recommended Independence Day (ID4) (1996) (rating 4)
#                  Movie in History  Rating  Weight Influence
# 1      Farewell to Arms, A (1932)     4.0    1.04         +
# 2   War of the Worlds, The (1953)     4.0    0.94         +
# 3         Dirty Dozen, The (1967)     4.0    0.21         +
# 4                 Lifeboat (1944)     5.0    0.07         +
# 0  For Whom the Bell Tolls (1943)     4.0   -1.17         -
#
# Step 4: Recommended Fighting Seabees, The (1944) (rating 4)
#                  Movie in History  Rating  Weight Influence
# 0   War of the Worlds, The (1953)     4.0    1.19         +
# 3                 Lifeboat (1944)     5.0    0.34         +
# 5         Dirty Dozen, The (1967)     4.0    0.09         +
# 4  For Whom the Bell Tolls (1943)     4.0   -0.25         -
# 2   Independence Day (ID4) (1996)     4.0   -0.57         -
# 1      Farewell to Arms, A (1932)     4.0   -0.68         -
#
# Step 5: Recommended Them! (1954) (rating 5)
#                  Movie in History  Rating  Weight Influence
# 1    Fighting Seabees, The (1944)     4.0    1.05         +
# 2   War of the Worlds, The (1953)     4.0    0.47         +
# 3      Farewell to Arms, A (1932)     4.0    0.34         +
# 4         Dirty Dozen, The (1967)     4.0    0.11         +
# 6   Independence Day (ID4) (1996)     4.0    0.00         +
# 5                 Lifeboat (1944)     5.0   -0.04         -
# 0  For Whom the Bell Tolls (1943)     4.0   -1.07         -
#
# Step 6: Recommended Aces: Iron Eagle III (1992) (rating 1)
#                  Movie in History  Rating  Weight Influence
# 0    Fighting Seabees, The (1944)     4.0    1.32         +
# 2   Independence Day (ID4) (1996)     4.0    0.75         +
# 4      Farewell to Arms, A (1932)     4.0    0.55         +
# 7                    Them! (1954)     5.0   -0.09         -
# 6         Dirty Dozen, The (1967)     4.0   -0.29         -
# 5                 Lifeboat (1944)     5.0   -0.43         -
# 3  For Whom the Bell Tolls (1943)     4.0   -0.65         -
# 1   War of the Worlds, The (1953)     4.0   -0.83         -
#
# Step 7: Recommended Force 10 from Navarone (1978) (rating 2)
#                  Movie in History  Rating  Weight Influence
# 0    Fighting Seabees, The (1944)     4.0    1.69         +
# 2         Dirty Dozen, The (1967)     4.0    0.27         +
# 5   Independence Day (ID4) (1996)     4.0    0.13         +
# 7  For Whom the Bell Tolls (1943)     4.0    0.01         +
# 6                    Them! (1954)     5.0   -0.02         -
# 4      Farewell to Arms, A (1932)     4.0   -0.19         -
# 3   War of the Worlds, The (1953)     4.0   -0.25         -
# 1                 Lifeboat (1944)     5.0   -1.20         -
#
# Step 8: Recommended Tora! Tora! Tora! (1970) (rating 3)
#                  Movie in History  Rating  Weight Influence
# 0   War of the Worlds, The (1953)     4.0    1.25         +
# 2    Fighting Seabees, The (1944)     4.0    0.81         +
# 4      Farewell to Arms, A (1932)     4.0    0.59         +
# 6                    Them! (1954)     5.0    0.27         +
# 7         Dirty Dozen, The (1967)     4.0   -0.02         -
# 5                 Lifeboat (1944)     5.0   -0.37         -
# 3   Independence Day (ID4) (1996)     4.0   -0.63         -
# 1  For Whom the Bell Tolls (1943)     4.0   -1.02         -
#
# Step 9: Recommended Rambo: First Blood Part II (1985) (rating 2)
#                  Movie in History  Rating  Weight Influence
# 0      Farewell to Arms, A (1932)     4.0    1.11         +
# 2    Fighting Seabees, The (1944)     4.0    0.99         +
# 4         Dirty Dozen, The (1967)     4.0    0.23         +
# 7   Independence Day (ID4) (1996)     4.0   -0.05         -
# 6  For Whom the Bell Tolls (1943)     4.0   -0.08         -
# 5   War of the Worlds, The (1953)     4.0   -0.18         -
# 3                 Lifeboat (1944)     5.0   -0.72         -
# 1                    Them! (1954)     5.0   -1.05         -
#
# Step 10: Recommended Hot Shots! Part Deux (1993) (rating 4)
#                  Movie in History  Rating  Weight Influence
# 1                    Them! (1954)     5.0    1.03         +
# 2    Fighting Seabees, The (1944)     4.0    0.93         +
# 5   Independence Day (ID4) (1996)     4.0    0.37         +
# 6   War of the Worlds, The (1953)     4.0    0.05         +
# 7         Dirty Dozen, The (1967)     4.0    0.04         +
# 4      Farewell to Arms, A (1932)     4.0   -0.50         -
# 3                 Lifeboat (1944)     5.0   -0.52         -
# 0  For Whom the Bell Tolls (1943)     4.0   -1.18         -
#
# ============================================================
# USER 67
# 1: Breakfast at Tiffany's (1961) (rating 5)
# 2: Do the Right Thing (1989) (rating 4)
# 3: Big Night (1996) (rating 5)
# 4: Miracle on 34th Street (1947) (rating 5)
# 5: Doctor Zhivago (1965) (rating 5)
# 6: Apartment, The (1960) (rating 5)
# 7: Prizzi's Honor (1985) (rating 4)
# 8: Deer Hunter, The (1978) (rating 2)
# 9: Rocky (1976) (rating 5)
# 10: Close Encounters of the Third Kind (1977) (rating 4)
#
# Step 1: Recommended Breakfast at Tiffany's (1961) (rating 5)
#                 Movie in History  Rating  Weight Influence
# 1       Kramer Vs. Kramer (1979)     4.0    1.17         +
# 2               Key Largo (1948)     5.0    0.92         +
# 3  Last Picture Show, The (1971)     4.0    0.74         +
# 4            My Left Foot (1989)     5.0   -0.49         -
# 0        Carnal Knowledge (1971)     4.0   -1.60         -
#
# Step 2: Recommended Do the Right Thing (1989) (rating 4)
#                 Movie in History  Rating  Weight Influence
# 0            My Left Foot (1989)     5.0    0.70         +
# 2  Last Picture Show, The (1971)     4.0    0.52         +
# 3  Breakfast at Tiffany's (1961)     5.0    0.26         +
# 5       Kramer Vs. Kramer (1979)     4.0   -0.00         -
# 4        Carnal Knowledge (1971)     4.0   -0.01         -
# 1               Key Largo (1948)     5.0   -0.62         -
#
# Step 3: Recommended Big Night (1996) (rating 5)
#                 Movie in History  Rating  Weight Influence
# 0            My Left Foot (1989)     5.0    1.39         +
# 1        Carnal Knowledge (1971)     4.0    1.30         +
# 4  Breakfast at Tiffany's (1961)     5.0    0.56         +
# 5  Last Picture Show, The (1971)     4.0    0.51         +
# 6      Do the Right Thing (1989)     4.0   -0.12         -
# 3               Key Largo (1948)     5.0   -1.08         -
# 2       Kramer Vs. Kramer (1979)     4.0   -1.17         -
#
# Step 4: Recommended Miracle on 34th Street (1947) (rating 5)
#                 Movie in History  Rating  Weight Influence
# 0      Do the Right Thing (1989)     4.0    0.77         +
# 2               Big Night (1996)     5.0    0.45         +
# 3       Kramer Vs. Kramer (1979)     4.0    0.44         +
# 7               Key Largo (1948)     5.0   -0.04         -
# 6        Carnal Knowledge (1971)     4.0   -0.06         -
# 5  Breakfast at Tiffany's (1961)     5.0   -0.41         -
# 4  Last Picture Show, The (1971)     4.0   -0.42         -
# 1            My Left Foot (1989)     5.0   -0.62         -
#
# Step 5: Recommended Doctor Zhivago (1965) (rating 5)
#                 Movie in History  Rating  Weight Influence
# 1  Last Picture Show, The (1971)     4.0    0.38         +
# 2               Big Night (1996)     5.0    0.32         +
# 3  Miracle on 34th Street (1947)     5.0    0.29         +
# 4        Carnal Knowledge (1971)     4.0    0.23         +
# 5  Breakfast at Tiffany's (1961)     5.0    0.14         +
# 8       Kramer Vs. Kramer (1979)     4.0    0.03         +
# 7      Do the Right Thing (1989)     4.0   -0.09         -
# 6               Key Largo (1948)     5.0   -0.10         -
# 0            My Left Foot (1989)     5.0   -0.43         -
#
# Step 6: Recommended Apartment, The (1960) (rating 5)
#                 Movie in History  Rating  Weight Influence
# 0  Miracle on 34th Street (1947)     5.0    0.42         +
# 3               Key Largo (1948)     5.0    0.26         +
# 5        Carnal Knowledge (1971)     4.0    0.15         +
# 7               Big Night (1996)     5.0    0.09         +
# 8  Breakfast at Tiffany's (1961)     5.0    0.07         +
# 9          Doctor Zhivago (1965)     5.0    0.05         +
# 6            My Left Foot (1989)     5.0   -0.14         -
# 4       Kramer Vs. Kramer (1979)     4.0   -0.15         -
# 2      Do the Right Thing (1989)     4.0   -0.30         -
# 1  Last Picture Show, The (1971)     4.0   -0.35         -
#
# Step 7: Recommended Prizzi's Honor (1985) (rating 4)
#                  Movie in History  Rating  Weight Influence
# 1   Miracle on 34th Street (1947)     5.0    0.48         +
# 3       Do the Right Thing (1989)     4.0    0.32         +
# 4                Key Largo (1948)     5.0    0.22         +
# 6           Apartment, The (1960)     5.0    0.13         +
# 8   Last Picture Show, The (1971)     4.0    0.12         +
# 9             My Left Foot (1989)     5.0    0.04         +
# 10  Breakfast at Tiffany's (1961)     5.0   -0.01         -
# 7           Doctor Zhivago (1965)     5.0   -0.12         -
# 5         Carnal Knowledge (1971)     4.0   -0.18         -
# 2                Big Night (1996)     5.0   -0.39         -
# 0        Kramer Vs. Kramer (1979)     4.0   -0.53         -
#
# Step 8: Recommended Deer Hunter, The (1978) (rating 2)
#                  Movie in History  Rating  Weight Influence
# 0                Big Night (1996)     5.0    0.57         +
# 2   Miracle on 34th Street (1947)     5.0    0.41         +
# 3           Prizzi's Honor (1985)     4.0    0.37         +
# 7        Kramer Vs. Kramer (1979)     4.0    0.10         +
# 10  Last Picture Show, The (1971)     4.0    0.03         +
# 11          Apartment, The (1960)     5.0   -0.01         -
# 9           Doctor Zhivago (1965)     5.0   -0.04         -
# 8                Key Largo (1948)     5.0   -0.09         -
# 6   Breakfast at Tiffany's (1961)     5.0   -0.13         -
# 5             My Left Foot (1989)     5.0   -0.17         -
# 4         Carnal Knowledge (1971)     4.0   -0.26         -
# 1       Do the Right Thing (1989)     4.0   -0.47         -
#
# Step 9: Recommended Rocky (1976) (rating 5)
#                  Movie in History  Rating  Weight Influence
# 1           Doctor Zhivago (1965)     5.0    0.29         +
# 3   Breakfast at Tiffany's (1961)     5.0    0.27         +
# 4           Prizzi's Honor (1985)     4.0    0.22         +
# 5           Apartment, The (1960)     5.0    0.17         +
# 6   Last Picture Show, The (1971)     4.0    0.16         +
# 10      Do the Right Thing (1989)     4.0    0.02         +
# 11               Big Night (1996)     5.0    0.00         +
# 9                Key Largo (1948)     5.0   -0.08         -
# 8        Kramer Vs. Kramer (1979)     4.0   -0.12         -
# 7             My Left Foot (1989)     5.0   -0.15         -
# 2         Carnal Knowledge (1971)     4.0   -0.27         -
# 0   Miracle on 34th Street (1947)     5.0   -0.32         -
#
# Step 10: Recommended Close Encounters of the Third Kind (1977) (rating 4)
#                  Movie in History  Rating  Weight Influence
# 1                Key Largo (1948)     5.0    0.28         +
# 3   Miracle on 34th Street (1947)     5.0    0.21         +
# 4                Big Night (1996)     5.0    0.12         +
# 5           Doctor Zhivago (1965)     5.0    0.11         +
# 6         Carnal Knowledge (1971)     4.0    0.09         +
# 10  Last Picture Show, The (1971)     4.0    0.08         +
# 12          Prizzi's Honor (1985)     4.0    0.02         +
# 11            My Left Foot (1989)     5.0   -0.03         -
# 9           Apartment, The (1960)     5.0   -0.08         -
# 7        Kramer Vs. Kramer (1979)     4.0   -0.09         -
# 8   Breakfast at Tiffany's (1961)     5.0   -0.09         -
# 2       Do the Right Thing (1989)     4.0   -0.23         -
# 0                    Rocky (1976)     5.0   -0.32         -
#
# ============================================================
# USER 316
# 1: Star Trek: The Motion Picture (1979) (rating 5)
# 2: Moonraker (1979) (rating 4)
# 3: Lawnmower Man, The (1992) (rating 3)
# 4: Lost World: Jurassic Park, The (1997) (rating 5)
# 5: Star Trek V: The Final Frontier (1989) (rating 5)
# 6: My Science Project (1985) (rating 3)
# 7: Alien³ (1992) (rating 4)
# 8: Return of the Fly (1959) (rating 3)
# 9: Back to the Future Part III (1990) (rating 4)
# 10: Fly, The (1958) (rating 3)
#
# Step 1: Recommended Star Trek: The Motion Picture (1979) (rating 5)
#                                                      Movie in History  Rating  Weight Influence
# 0                                      Flight of the Navigator (1986)     5.0    1.05         +
# 2  Adventures of Buckaroo Bonzai Across the 8th Dimension, The (1984)     5.0    0.39         +
# 3                                                  Deep Impact (1998)     4.0    0.39         +
# 4                                      Star Trek: Insurrection (1998)     5.0   -0.34         -
# 1                                                         Tron (1982)     5.0   -0.94         -
#
# Step 2: Recommended Moonraker (1979) (rating 4)
#                                                      Movie in History  Rating  Weight Influence
# 1  Adventures of Buckaroo Bonzai Across the 8th Dimension, The (1984)     5.0    0.64         +
# 2                                      Flight of the Navigator (1986)     5.0    0.47         +
# 5                                                  Deep Impact (1998)     4.0    0.14         +
# 4                                      Star Trek: Insurrection (1998)     5.0   -0.30         -
# 3                                Star Trek: The Motion Picture (1979)     5.0   -0.31         -
# 0                                                         Tron (1982)     5.0   -0.77         -
#
# Step 3: Recommended Lawnmower Man, The (1992) (rating 3)
#                                                      Movie in History  Rating  Weight Influence
# 1  Adventures of Buckaroo Bonzai Across the 8th Dimension, The (1984)     5.0    0.33         +
# 3                                Star Trek: The Motion Picture (1979)     5.0    0.14         +
# 4                                                  Deep Impact (1998)     4.0    0.11         +
# 6                                      Star Trek: Insurrection (1998)     5.0   -0.00         -
# 5                                      Flight of the Navigator (1986)     5.0   -0.07         -
# 2                                                    Moonraker (1979)     4.0   -0.14         -
# 0                                                         Tron (1982)     5.0   -0.49         -
#
# Step 4: Recommended Lost World: Jurassic Park, The (1997) (rating 5)
#                                                      Movie in History  Rating  Weight Influence
# 0                                      Flight of the Navigator (1986)     5.0    0.63         +
# 4                                      Star Trek: Insurrection (1998)     5.0    0.08         +
# 5  Adventures of Buckaroo Bonzai Across the 8th Dimension, The (1984)     5.0    0.03         +
# 6                                                         Tron (1982)     5.0   -0.01         -
# 3                                Star Trek: The Motion Picture (1979)     5.0   -0.09         -
# 2                                                    Moonraker (1979)     4.0   -0.25         -
# 1                                                  Deep Impact (1998)     4.0   -0.27         -
#
# Step 5: Recommended Star Trek V: The Final Frontier (1989) (rating 5)
#                                                      Movie in History  Rating  Weight Influence
# 0                                      Flight of the Navigator (1986)     5.0    1.21         +
# 3                               Lost World: Jurassic Park, The (1997)     5.0    0.43         +
# 7  Adventures of Buckaroo Bonzai Across the 8th Dimension, The (1984)     5.0    0.07         +
# 6                                      Star Trek: Insurrection (1998)     5.0   -0.09         -
# 5                                                  Deep Impact (1998)     4.0   -0.16         -
# 4                                                    Moonraker (1979)     4.0   -0.25         -
# 2                                                         Tron (1982)     5.0   -0.46         -
# 1                                Star Trek: The Motion Picture (1979)     5.0   -0.51         -
#
# Step 6: Recommended My Science Project (1985) (rating 3)
#                                                      Movie in History  Rating  Weight Influence
# 1                                      Flight of the Navigator (1986)     5.0    0.70         +
# 3                               Lost World: Jurassic Park, The (1997)     5.0    0.50         +
# 5                                                  Deep Impact (1998)     4.0    0.15         +
# 7                                                    Moonraker (1979)     4.0    0.04         +
# 8                                                         Tron (1982)     5.0    0.01         +
# 6  Adventures of Buckaroo Bonzai Across the 8th Dimension, The (1984)     5.0   -0.13         -
# 4                                      Star Trek: Insurrection (1998)     5.0   -0.34         -
# 2                              Star Trek V: The Final Frontier (1989)     5.0   -0.53         -
# 0                                Star Trek: The Motion Picture (1979)     5.0   -0.84         -
#
# Step 7: Recommended Alien³ (1992) (rating 4)
#                                                      Movie in History  Rating  Weight Influence
# 2                                                    Moonraker (1979)     4.0    0.22         +
# 3  Adventures of Buckaroo Bonzai Across the 8th Dimension, The (1984)     5.0    0.21         +
# 4                               Lost World: Jurassic Park, The (1997)     5.0    0.17         +
# 5                                                         Tron (1982)     5.0    0.15         +
# 8                                                  Deep Impact (1998)     4.0   -0.03         -
# 7                                      Flight of the Navigator (1986)     5.0   -0.09         -
# 6                              Star Trek V: The Final Frontier (1989)     5.0   -0.11         -
# 1                                      Star Trek: Insurrection (1998)     5.0   -0.27         -
# 0                                Star Trek: The Motion Picture (1979)     5.0   -0.50         -
#
# Step 8: Recommended Return of the Fly (1959) (rating 3)
#                                                      Movie in History  Rating  Weight Influence
# 0                                                    Moonraker (1979)     4.0    0.89         +
# 3  Adventures of Buckaroo Bonzai Across the 8th Dimension, The (1984)     5.0    0.34         +
# 5                                                         Tron (1982)     5.0    0.12         +
# 9                               Lost World: Jurassic Park, The (1997)     5.0    0.02         +
# 8                                      Star Trek: Insurrection (1998)     5.0   -0.04         -
# 6                                                       Alien³ (1992)     4.0   -0.06         -
# 7                                Star Trek: The Motion Picture (1979)     5.0   -0.06         -
# 4                                      Flight of the Navigator (1986)     5.0   -0.34         -
# 2                                                  Deep Impact (1998)     4.0   -0.50         -
# 1                              Star Trek V: The Final Frontier (1989)     5.0   -0.53         -
#
# Step 9: Recommended Back to the Future Part III (1990) (rating 4)
#                                                      Movie in History  Rating  Weight Influence
# 2                                                  Deep Impact (1998)     4.0    0.22         +
# 4                               Lost World: Jurassic Park, The (1997)     5.0    0.19         +
# 6                              Star Trek V: The Final Frontier (1989)     5.0    0.13         +
# 7                                      Flight of the Navigator (1986)     5.0    0.09         +
# 9                                                       Alien³ (1992)     4.0   -0.06         -
# 8  Adventures of Buckaroo Bonzai Across the 8th Dimension, The (1984)     5.0   -0.08         -
# 5                                Star Trek: The Motion Picture (1979)     5.0   -0.18         -
# 3                                                    Moonraker (1979)     4.0   -0.19         -
# 1                                                         Tron (1982)     5.0   -0.25         -
# 0                                      Star Trek: Insurrection (1998)     5.0   -0.27         -
#
# Step 10: Recommended Fly, The (1958) (rating 3)
#                                                       Movie in History  Rating  Weight Influence
# 1                                       Flight of the Navigator (1986)     5.0    0.58         +
# 2   Adventures of Buckaroo Bonzai Across the 8th Dimension, The (1984)     5.0    0.50         +
# 3                                                   Deep Impact (1998)     4.0    0.43         +
# 9                                Lost World: Jurassic Park, The (1997)     5.0    0.08         +
# 10                                      Star Trek: Insurrection (1998)     5.0   -0.00         -
# 8                               Star Trek V: The Final Frontier (1989)     5.0   -0.09         -
# 7                                   Back to the Future Part III (1990)     4.0   -0.13         -
# 6                                                          Tron (1982)     5.0   -0.16         -
# 5                                                        Alien³ (1992)     4.0   -0.24         -
# 4                                 Star Trek: The Motion Picture (1979)     5.0   -0.36         -
# 0                                                     Moonraker (1979)     4.0   -0.65         -
