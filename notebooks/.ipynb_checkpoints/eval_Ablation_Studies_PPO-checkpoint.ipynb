# %%
import os
import numpy as np
import pandas as pd
import random
import pickle
import time
import port_for
import subprocess

# Env
import gymnasium as gym
from gymnasium import spaces
import torch

# Algo
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="6"

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
seed = 316
random.seed(seed)
np.random.seed(seed)

# %%
def convert(seconds):
    seconds = seconds % (24 * 3600)
    hour = seconds // 3600
    seconds %= 3600
    minutes = seconds // 60
    seconds %= 60

    return "%d:%02d:%02d" % (hour, minutes, seconds)

# %% [markdown]
# # Load Data & Model

# %%
# Load data
# train_sequences and test_sequences are dictionaries like user_sequences
# Keys: UserIDs (ints)
# Values: list of tuples, each tuple is (movieID, rating)

# Dictionary maps for printing
with open('../data/idx2user.pkl', 'rb') as f:
    idx2user = pickle.load(f)
with open('../data/user2idx.pkl', 'rb') as f:
    user2idx = pickle.load(f)

with open('../data/train_sequences_idx.pkl', 'rb') as f:
    train_sequences_idx = pickle.load(f)
with open('../data/test_sequences_idx.pkl', 'rb') as f:
    test_sequences_idx = pickle.load(f)

# ratings_dict is a Dictionary
# Each key is a tuple (user index, movie index)
with open('../data/ratings_dict.pkl', 'rb') as f:
    ratings_dict = pickle.load(f)

user_embeddings = np.load('../data/user_embeddings.npy')
movie_embeddings = np.load('../data/movie_embeddings.npy')

# Dictionary that maps Movie Index to Title for Quick Lookup
with open('../data/movie_index_to_title.pkl', 'rb') as f:
    movie_index_to_title = pickle.load(f)

# Dictionary that maps MovieID to Title for Quick Lookup
with open('../data/movie_id_to_title.pkl', 'rb') as f:
    movie_id_to_title = pickle.load(f)

# %% [markdown]
# # Env

# %%
class EvalPPORecommendationEnv(gym.Env):
    def __init__(self, 
                 train_sequences_idx,      # dict: user_idx -> [movie_idx, ...]
                 test_sequences_idx,       # dict: user_idx -> [movie_idx, ...]
                 ratings_dict,             # (user_idx, movie_idx) -> rating
                 user_embeddings, movie_embeddings,
                 evaluable_users,
                 n_history=5, T_max=10):
        super().__init__()
        self.train = train_sequences_idx
        self.test = test_sequences_idx
        self.ratings = ratings_dict
        self.user_embeddings = user_embeddings
        self.movie_embeddings = movie_embeddings
        self.evaluable_users = evaluable_users
        self.n_history = n_history
        self.T_max = T_max

        self.k = movie_embeddings.shape[1]
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(3*self.k,), dtype=np.float32)
        self.action_space = spaces.Box(low=-1.0, high=1.0, shape=(self.k,), dtype=np.float32)
        self.item_weights = np.ones(self.n_history)

        self.current_user = None
        self.history = None
        self.candidate_items = None
        self.recommended_set = None
        self.step_count = 0

    def _get_state(self, user_idx, history_indices):
        u = self.user_embeddings[user_idx]
        weights = np.exp(self.item_weights) / np.sum(np.exp(self.item_weights))
        hist_embs = self.movie_embeddings[history_indices]
        weighted_avg = np.sum(hist_embs * weights[:, np.newaxis], axis=0)
        u_g = u * weighted_avg
        return np.concatenate([u, u_g, weighted_avg]).astype(np.float32)

    # def _get_state(self, user_idx, history_indices):
    #     u = self.user_embeddings[user_idx]
        
    #     # L = len(history_indices)
    #     # weights = np.exp(self.item_weights[:L])
    #     # weights = weights / np.sum(weights)
    #     L = len(history_indices)
    #     weights = np.ones(L) / L  # simple average
    
    #     hist_embs = self.movie_embeddings[history_indices]
    #     weighted_avg = np.sum(hist_embs * weights[:, np.newaxis], axis=0)
        
    #     u_g = u * weighted_avg
    #     return np.concatenate([u, u_g, weighted_avg]).astype(np.float32)

    def reset(self, *, seed=None, options=None):
        if seed is not None:
            np.random.seed(seed)

        # During evaluation, I'll always call reset(options={'user_idx': user_idx})
        # options lets me pass a specific user Index
        if options is not None and 'user_idx' in options:
            user_idx = options['user_idx']
        else:
            # NOTE: This should never happen b/c reset() has options passed in with user_idx
            # And the eval loop is iterating thru all user indices.
            user_idx = np.random.choice(self.evaluable_users)
        self.current_user = user_idx

        # Build positive history from training (last n_history items with rating >=4)
        pos_items = []
        for m in self.train[user_idx]:
            if self.ratings.get((user_idx, m), 0) >= 4:
                pos_items.append(m)
        self.history = pos_items[-self.n_history:].copy()

        # Set initial state
        self.candidate_items = set(self.test[user_idx])
        self.recommended_set = set()
        self.step_count = 0
        state = self._get_state(user_idx, self.history)
        return state, {}

    def step(self, action):
        candidates = list(self.candidate_items - self.recommended_set)
        if not candidates:
            next_state = self._get_state(self.current_user, self.history)
            return next_state, 0.0, True, False, {}

        cand_emb = self.movie_embeddings[candidates]
        scores = cand_emb @ action
        best_idx = np.argmax(scores)
        selected_item = candidates[best_idx]

        rating = self.ratings.get((self.current_user, selected_item), 0)
        reward = (rating - 3) / 2.0

        new_history = self.history.copy()
        if reward > 0:
            new_history = new_history[1:] + [selected_item]

        self.recommended_set.add(selected_item)
        self.step_count += 1

        terminated = (len(self.candidate_items - self.recommended_set) == 0)
        truncated = (self.step_count >= self.T_max)

        next_state = self._get_state(self.current_user, new_history)
        self.history = new_history

        info = {'selected_item': selected_item, 'rating': rating, 'reward': reward, 'step': self.step_count}
        return next_state, reward, terminated, truncated, info

# %%
def get_ground_truth(env, user_idx):
    """
        Returns a set of movie INDICES that the user rated positively (4 or 5)
    """
    truth = set()
    for movie_idx in env.test[user_idx]:
        if env.ratings.get((user_idx, movie_idx), 0) >= 4:
            truth.add(movie_idx)
    return truth

# %%
def evaluate_ppo(model, env, evaluable_users, top_k_list=[5, 10], max_steps=10, rating_threshold=4):    
    # Store all session trajectories
    all_sessions = {}
    metrics = {k: {'precision': [], 'ndcg': []} for k in top_k_list}
    user_IDs_to_explain = [1, 3, 40, 67, 316]

    for user_index in evaluable_users:
        user_id = idx2user[user_index]
        
        obs, _ = env.reset(options={'user_idx': user_index})
        recommended_items = []
        step = 0
        done = False

        # Get the list of movie indexes rated by the user index
        test_items = env.test[user_index]

        initial_history = env.history.copy()
        current_history = initial_history

        # Ground truth: positive items in test set (using env's test data)
        ground_truth = get_ground_truth(env, user_index)
        
        trajectory = {
            'user_id': idx2user[user_index],
            'user_idx': user_index,
            'initial_history': initial_history,
            'steps': [],
            'ground_truth': ground_truth,
            'test_seq': test_items
        }
        
        if user_id in user_IDs_to_explain:
            print("="*80)
            print(f"USER ID: {user_id} (Index: {user_index})")
            print(f"  Ground truth size: {len(ground_truth)}")
            print(f"Test Set Favorites (Ground Truth):")
            for movie_index in test_items:
                rating = ratings_dict[(user_index, movie_index)]
                if rating >= rating_threshold:
                    title = movie_index_to_title.get(movie_index, 'Unknown')
                    print(f"  - {title} (Actual Rating: {rating})")      

            print("Model Recommendations:")
            print(f"{'Rank':<5} | {'Title':<40} | {'Score':<10} | {'Hit?':<6} | {'Actual Rating':<6}")
            print("-" * 80)   

        # Run the session and SAVE the trajectory
        while not done and step < max_steps:
            action, _ = model.predict(obs, deterministic=True)
            obs, reward, terminated, truncated, info = env.step(action)
            done = terminated or truncated
            
            if 'selected_item' in info:
                # info keys: 'selected_item', 'rating', 'reward', 'step'
                selected_item = info['selected_item']
                rating = info['rating']

                target_emb = env.movie_embeddings[selected_item]
                score = np.dot(action, target_emb)
                recommended_items.append(selected_item)
                
                # SAVE
                step_data = {
                    'step': step + 1,
                    'recommended_movie_idx': selected_item,
                    'recommended_movie_title': movie_index_to_title.get(selected_item, 'Unknown'),
                    'rating': rating,
                    'score': score,
                    'reward': reward,
                    'history_at_time': current_history.copy()
                }
                trajectory['steps'].append(step_data)

                if reward > 0:
                    current_history.append(selected_item)
                
                movie_title = movie_index_to_title.get(selected_item, "Unknown")
                if user_id in user_IDs_to_explain:
                    is_hit = "YES" if selected_item in ground_truth else "NO"
                    print(f"{step+1:<5} | {movie_title[:40]:<40} | {score: <10.4f}  | {is_hit:<6} | {rating:<6}")
            step += 1

        # Save trajectory
        all_sessions[user_index] = trajectory

        # Compute precision@k and NDCG@K for k=5 and k=10 for THIS current user
        for k in top_k_list:
            # Calculate precision@K
            top_k = recommended_items[:k]
            hits = sum(1 for m in top_k if m in ground_truth)
            precision = hits / k
            # Calculate NDCG@K
            dcg = sum(1 / np.log2(i+2) for i, m in enumerate(top_k) if m in ground_truth)
            idcg = sum(1 / np.log2(i+2) for i in range(min(len(ground_truth), k)))
            ndcg = dcg / idcg if idcg > 0 else 0.0
            # Store results
            metrics[k]['precision'].append(precision)
            metrics[k]['ndcg'].append(ndcg)

        # if user_id in user_IDs_to_explain:
            # print(f"    Precision@{k}: {metrics[k]['precision'][-1]:.4f}, NDCG@{k}: {metrics[k]['ndcg'][-1]:.4f}\n")

    # Outside the for loop now...
    # Calculate AVG. the precision@K & NDCG@K values for k=5 and k=10 FOR ALL USERS
    results = {}
    for k in top_k_list:
        results[f'Precision@{k}'] = np.mean(metrics[k]['precision'])
        results[f'NDCG@{k}'] = np.mean(metrics[k]['ndcg'])
    return all_sessions, results

# %% [markdown]
# # Eval

# %%
def get_evaluable_users(min_required=5):
# Create list of User Indices that you can legitimately evaluate
    evaluable_users = []
    for user_idx in train_sequences_idx.keys():
        # Count positive items in training
        pos_train = 0
        for movie_idx in train_sequences_idx[user_idx]:
            rating = ratings_dict.get((user_idx, movie_idx), 0)
            if rating >= 4:
                pos_train += 1
    
        # if # of positively rated movies in the train set < 5, skip the rest of the for loop
        if pos_train < min_required:
            continue
        
        # Check test set has at least one item
        test_items = test_sequences_idx.get(user_idx, [])
        if len(test_items) == 0:
            continue
        
        # Check test set has at least one positive item
        has_positive_test = False
        for movie_idx in test_items:
            rating = ratings_dict.get((user_idx, movie_idx), 0)
            if rating >= 4:
                has_positive_test = True
                break
        
        if not has_positive_test:
            continue
        
        evaluable_users.append(user_idx)

    return evaluable_users

# %%
all_Ab_study_eval_results = {}

history_lengths = [1, 3, 5, 7, 10]
episode_lengths = [10, 50, 100, 500]
ab_study_id = 1

version_number = 3
total_timesteps = 500_000

for n in history_lengths:
    evaluable_users = get_evaluable_users(n)
    print(f"Number of evaluable users: {len(evaluable_users)}")

    for t in episode_lengths:
        print(f"Ablation Study {ab_study_id}: n={n}, T_max={t}")
        model = PPO.load(f"../models/PPO_AbStudy_{ab_study_id}_n{n}_t{t}_Ver_{version_number}_{total_timesteps}")
        
        env = EvalPPORecommendationEnv(
            train_sequences_idx=train_sequences_idx,
            test_sequences_idx=test_sequences_idx,
            ratings_dict=ratings_dict,
            user_embeddings=user_embeddings,
            movie_embeddings=movie_embeddings,
            evaluable_users=evaluable_users,
            n_history=n,
            T_max=t
        )
        
        # Evaluate
        sessions, results = evaluate_ppo(model, env, evaluable_users, top_k_list=[5, 10], max_steps=10)
        print("PPO Ablation Study Evaluation on Test Set")
        for metric, value in results.items():
            print(f"{metric}: {value:.4f}")
            
        all_Ab_study_eval_results[ab_study_id] = {
            'n_history': n,
            'T_max': t,
            **results
        }
        # # Save the trajectory
        # with open(f'../results/PPO_AbStudy{ab_study_id}_n{n}_t{t}_session_trajectories.pkl', 'wb') as f:
        #     pickle.dump(sessions, f)

        ab_study_id += 1
# Out:
# Number of evaluable users: 5975
# Ablation Study 1: n=1, T_max=10
# ================================================================================
# USER ID: 1 (Index: 0)
#   Ground truth size: 9
# Test Set Favorites (Ground Truth):
#   - Beauty and the Beast (1991) (Actual Rating: 5.0)
#   - Aladdin (1992) (Actual Rating: 4.0)
#   - Toy Story (1995) (Actual Rating: 5.0)
#   - Bug's Life, A (1998) (Actual Rating: 5.0)
#   - Antz (1998) (Actual Rating: 4.0)
#   - Hunchback of Notre Dame, The (1996) (Actual Rating: 4.0)
#   - Hercules (1997) (Actual Rating: 4.0)
#   - Mulan (1998) (Actual Rating: 4.0)
#   - Pocahontas (1995) (Actual Rating: 5.0)
# Model Recommendations:
# Rank  | Title                                    | Score      | Hit?   | Actual Rating
# --------------------------------------------------------------------------------
# 1     | Bug's Life, A (1998)                     | 2.8508      | YES    | 5.0
# 2     | Toy Story (1995)                         | 2.4570      | YES    | 5.0
# 3     | Beauty and the Beast (1991)              | 2.4401      | YES    | 5.0
# 4     | Aladdin (1992)                           | 2.3901      | YES    | 4.0
# 5     | Close Shave, A (1995)                    | 2.1784      | NO     | 3.0
# 6     | Antz (1998)                              | 2.0065      | YES    | 4.0
# 7     | Mulan (1998)                             | 1.9229      | YES    | 4.0
# 8     | Tarzan (1999)                            | 1.4452      | NO     | 3.0
# 9     | Hercules (1997)                          | 1.0352      | YES    | 4.0
# 10    | Hunchback of Notre Dame, The (1996)      | 1.1721      | YES    | 4.0
# ================================================================================
# USER ID: 3 (Index: 2)
#   Ground truth size: 6
# Test Set Favorites (Ground Truth):
#   - Fish Called Wanda, A (1988) (Actual Rating: 5.0)
#   - Stand by Me (1986) (Actual Rating: 5.0)
#   - Bug's Life, A (1998) (Actual Rating: 5.0)
#   - Caddyshack (1980) (Actual Rating: 5.0)
#   - Happy Gilmore (1996) (Actual Rating: 4.0)
#   - Little Mermaid, The (1989) (Actual Rating: 4.0)
# Model Recommendations:
# Rank  | Title                                    | Score      | Hit?   | Actual Rating
# --------------------------------------------------------------------------------
# 1     | Stand by Me (1986)                       | 3.2233      | YES    | 5.0
# 2     | Hollywood Knights, The (1980)            | 3.3770      | NO     | 2.0
# 3     | Bug's Life, A (1998)                     | 2.8168      | YES    | 5.0
# 4     | Naked Gun: From the Files of Police Squa | 2.5529      | NO     | 3.0
# 5     | Fish Called Wanda, A (1988)              | 2.5016      | YES    | 5.0
# 6     | Happy Gilmore (1996)                     | 2.5491      | YES    | 4.0
# 7     | Groundhog Day (1993)                     | 2.5958      | NO     | 2.0
# 8     | Back to the Future (1985)                | 2.5214      | NO     | 3.0
# 9     | Caddyshack (1980)                        | 1.9663      | YES    | 5.0
# 10    | Full Monty, The (1997)                   | 1.9068      | NO     | 2.0
# ================================================================================
# USER ID: 40 (Index: 39)
#   Ground truth size: 9
# Test Set Favorites (Ground Truth):
#   - Captain Horatio Hornblower (1951) (Actual Rating: 4.0)
#   - Flying Tigers (1942) (Actual Rating: 4.0)
#   - Forrest Gump (1994) (Actual Rating: 4.0)
#   - Longest Day, The (1962) (Actual Rating: 4.0)
#   - Them! (1954) (Actual Rating: 5.0)
#   - Fighting Seabees, The (1944) (Actual Rating: 4.0)
#   - Crimson Tide (1995) (Actual Rating: 4.0)
#   - Independence Day (ID4) (1996) (Actual Rating: 4.0)
#   - Hot Shots! Part Deux (1993) (Actual Rating: 4.0)
# Model Recommendations:
# Rank  | Title                                    | Score      | Hit?   | Actual Rating
# --------------------------------------------------------------------------------
# 1     | Pork Chop Hill (1959)                    | 2.9286      | NO     | 3.0
# 2     | Independence Day (ID4) (1996)            | 2.5754      | YES    | 4.0
# 3     | Fighting Seabees, The (1944)             | 2.3666      | YES    | 4.0
# 4     | Force 10 from Navarone (1978)            | 2.2222      | NO     | 2.0
# 5     | Forrest Gump (1994)                      | 1.9416      | YES    | 4.0
# 6     | South Pacific (1958)                     | 1.8537      | NO     | 3.0
# 7     | Longest Day, The (1962)                  | 1.5848      | YES    | 4.0
# 8     | Hot Shots! Part Deux (1993)              | 2.1316      | YES    | 4.0
# 9     | Flying Tigers (1942)                     | 1.7210      | YES    | 4.0
# 10    | Iron Eagle II (1988)                     | 1.4729      | NO     | 1.0
# ================================================================================
# USER ID: 67 (Index: 66)
#   Ground truth size: 12
# Test Set Favorites (Ground Truth):
#   - Apollo 13 (1995) (Actual Rating: 5.0)
#   - Prizzi's Honor (1985) (Actual Rating: 4.0)
#   - Doctor Zhivago (1965) (Actual Rating: 5.0)
#   - Close Encounters of the Third Kind (1977) (Actual Rating: 4.0)
#   - Do the Right Thing (1989) (Actual Rating: 4.0)
#   - Rocky (1976) (Actual Rating: 5.0)
#   - Miracle on 34th Street (1947) (Actual Rating: 5.0)
#   - Ben-Hur (1959) (Actual Rating: 5.0)
#   - Apartment, The (1960) (Actual Rating: 5.0)
#   - Big Night (1996) (Actual Rating: 5.0)
#   - Driving Miss Daisy (1989) (Actual Rating: 4.0)
#   - Breakfast at Tiffany's (1961) (Actual Rating: 5.0)
# Model Recommendations:
# Rank  | Title                                    | Score      | Hit?   | Actual Rating
# --------------------------------------------------------------------------------
# 1     | Big Night (1996)                         | 3.9460      | YES    | 5.0
# 2     | Ben-Hur (1959)                           | 2.9852      | YES    | 5.0
# 3     | Breakfast at Tiffany's (1961)            | 3.3720      | YES    | 5.0
# 4     | Rocky (1976)                             | 2.6951      | YES    | 5.0
# 5     | Prizzi's Honor (1985)                    | 2.7485      | YES    | 4.0
# 6     | Do the Right Thing (1989)                | 2.9407      | YES    | 4.0
# 7     | Apartment, The (1960)                    | 3.1229      | YES    | 5.0
# 8     | Doctor Zhivago (1965)                    | 2.5747      | YES    | 5.0
# 9     | Apollo 13 (1995)                         | 2.2054      | YES    | 5.0
# 10    | Driving Miss Daisy (1989)                | 2.0393      | YES    | 4.0
# ================================================================================
# USER ID: 316 (Index: 315)
#   Ground truth size: 9
# Test Set Favorites (Ground Truth):
#   - Moonraker (1979) (Actual Rating: 4.0)
#   - Alien³ (1992) (Actual Rating: 4.0)
#   - 2010 (1984) (Actual Rating: 4.0)
#   - Star Trek: The Motion Picture (1979) (Actual Rating: 5.0)
#   - Lost World: Jurassic Park, The (1997) (Actual Rating: 5.0)
#   - Cube (1997) (Actual Rating: 4.0)
#   - Stepford Wives, The (1975) (Actual Rating: 4.0)
#   - Back to the Future Part III (1990) (Actual Rating: 4.0)
#   - Star Trek V: The Final Frontier (1989) (Actual Rating: 5.0)
# Model Recommendations:
# Rank  | Title                                    | Score      | Hit?   | Actual Rating
# --------------------------------------------------------------------------------
# 1     | Fly, The (1958)                          | 2.1267      | NO     | 3.0
# 2     | Moonraker (1979)                         | 1.7680      | YES    | 4.0
# 3     | Parasite (1982)                          | 1.5457      | NO     | 2.0
# 4     | Star Trek: The Motion Picture (1979)     | 1.3182      | YES    | 5.0
# 5     | 2010 (1984)                              | 1.3235      | YES    | 4.0
# 6     | Alien³ (1992)                            | 0.7827      | YES    | 4.0
# 7     | Cube (1997)                              | 1.7445      | YES    | 4.0
# 8     | Back to the Future Part III (1990)       | 0.7912      | YES    | 4.0
# 9     | Lost World: Jurassic Park, The (1997)    | 0.2302      | YES    | 5.0
# 10    | Conquest of the Planet of the Apes (1972 | 0.2977      | NO     | 3.0
# PPO Ablation Study Evaluation on Test Set
# Precision@5: 0.6882
# NDCG@5: 0.7333
# Precision@10: 0.6073
# NDCG@10: 0.7616
# Ablation Study 2: n=1, T_max=50
# ================================================================================
# USER ID: 1 (Index: 0)
#   Ground truth size: 9
# Test Set Favorites (Ground Truth):
#   - Beauty and the Beast (1991) (Actual Rating: 5.0)
#   - Aladdin (1992) (Actual Rating: 4.0)
#   - Toy Story (1995) (Actual Rating: 5.0)
#   - Bug's Life, A (1998) (Actual Rating: 5.0)
#   - Antz (1998) (Actual Rating: 4.0)
#   - Hunchback of Notre Dame, The (1996) (Actual Rating: 4.0)
#   - Hercules (1997) (Actual Rating: 4.0)
#   - Mulan (1998) (Actual Rating: 4.0)
#   - Pocahontas (1995) (Actual Rating: 5.0)
# Model Recommendations:
# Rank  | Title                                    | Score      | Hit?   | Actual Rating
# --------------------------------------------------------------------------------
# 1     | Beauty and the Beast (1991)              | 2.7803      | YES    | 5.0
# 2     | Hercules (1997)                          | 2.7667      | YES    | 4.0
# 3     | Close Shave, A (1995)                    | 2.5478      | NO     | 3.0
# 4     | Antz (1998)                              | 2.5173      | YES    | 4.0
# 5     | Mulan (1998)                             | 2.3523      | YES    | 4.0
# 6     | Bug's Life, A (1998)                     | 2.3331      | YES    | 5.0
# 7     | Tarzan (1999)                            | 2.0359      | NO     | 3.0
# 8     | Aladdin (1992)                           | 1.8945      | YES    | 4.0
# 9     | Toy Story (1995)                         | 1.6900      | YES    | 5.0
# 10    | Hunchback of Notre Dame, The (1996)      | 0.7366      | YES    | 4.0
# ================================================================================
# USER ID: 3 (Index: 2)
#   Ground truth size: 6
# Test Set Favorites (Ground Truth):
#   - Fish Called Wanda, A (1988) (Actual Rating: 5.0)
#   - Stand by Me (1986) (Actual Rating: 5.0)
#   - Bug's Life, A (1998) (Actual Rating: 5.0)
#   - Caddyshack (1980) (Actual Rating: 5.0)
#   - Happy Gilmore (1996) (Actual Rating: 4.0)
#   - Little Mermaid, The (1989) (Actual Rating: 4.0)
# Model Recommendations:
# Rank  | Title                                    | Score      | Hit?   | Actual Rating
# --------------------------------------------------------------------------------
# 1     | Groundhog Day (1993)                     | 2.7622      | NO     | 2.0
# 2     | Fish Called Wanda, A (1988)              | 2.2136      | YES    | 5.0
# 3     | Little Mermaid, The (1989)               | 2.1351      | YES    | 4.0
# 4     | Bug's Life, A (1998)                     | 2.0443      | YES    | 5.0
# 5     | Hollywood Knights, The (1980)            | 1.6643      | NO     | 2.0
# 6     | Back to the Future (1985)                | 1.5324      | NO     | 3.0
# 7     | Stand by Me (1986)                       | 1.4969      | YES    | 5.0
# 8     | Full Monty, The (1997)                   | 1.1346      | NO     | 2.0
# 9     | Caddyshack (1980)                        | 0.9207      | YES    | 5.0
# 10    | Happy Gilmore (1996)                     | 0.5182      | YES    | 4.0
# ================================================================================
# USER ID: 40 (Index: 39)
#   Ground truth size: 9
# Test Set Favorites (Ground Truth):
#   - Captain Horatio Hornblower (1951) (Actual Rating: 4.0)
#   - Flying Tigers (1942) (Actual Rating: 4.0)
#   - Forrest Gump (1994) (Actual Rating: 4.0)
#   - Longest Day, The (1962) (Actual Rating: 4.0)
#   - Them! (1954) (Actual Rating: 5.0)
#   - Fighting Seabees, The (1944) (Actual Rating: 4.0)
#   - Crimson Tide (1995) (Actual Rating: 4.0)
#   - Independence Day (ID4) (1996) (Actual Rating: 4.0)
#   - Hot Shots! Part Deux (1993) (Actual Rating: 4.0)
# Model Recommendations:
# Rank  | Title                                    | Score      | Hit?   | Actual Rating
# --------------------------------------------------------------------------------
# 1     | Longest Day, The (1962)                  | 3.5964      | YES    | 4.0
# 2     | Fighting Seabees, The (1944)             | 2.8450      | YES    | 4.0
# 3     | Pork Chop Hill (1959)                    | 3.1365      | NO     | 3.0
# 4     | Forrest Gump (1994)                      | 2.3958      | YES    | 4.0
# 5     | Crimson Tide (1995)                      | 2.0008      | YES    | 4.0
# 6     | Force 10 from Navarone (1978)            | 1.3698      | NO     | 2.0
# 7     | Independence Day (ID4) (1996)            | 1.2875      | YES    | 4.0
# 8     | Mars Attacks! (1996)                     | 1.4098      | NO     | 3.0
# 9     | South Pacific (1958)                     | 1.3906      | NO     | 3.0
# 10    | Captain Horatio Hornblower (1951)        | 0.8971      | YES    | 4.0
# ================================================================================
# USER ID: 67 (Index: 66)
#   Ground truth size: 12
# Test Set Favorites (Ground Truth):
#   - Apollo 13 (1995) (Actual Rating: 5.0)
#   - Prizzi's Honor (1985) (Actual Rating: 4.0)
#   - Doctor Zhivago (1965) (Actual Rating: 5.0)
#   - Close Encounters of the Third Kind (1977) (Actual Rating: 4.0)
#   - Do the Right Thing (1989) (Actual Rating: 4.0)
#   - Rocky (1976) (Actual Rating: 5.0)
#   - Miracle on 34th Street (1947) (Actual Rating: 5.0)
#   - Ben-Hur (1959) (Actual Rating: 5.0)
#   - Apartment, The (1960) (Actual Rating: 5.0)
#   - Big Night (1996) (Actual Rating: 5.0)
#   - Driving Miss Daisy (1989) (Actual Rating: 4.0)
#   - Breakfast at Tiffany's (1961) (Actual Rating: 5.0)
# Model Recommendations:
# Rank  | Title                                    | Score      | Hit?   | Actual Rating
# --------------------------------------------------------------------------------
# 1     | Ben-Hur (1959)                           | 3.7233      | YES    | 5.0
# 2     | Rocky (1976)                             | 3.0967      | YES    | 5.0
# 3     | Driving Miss Daisy (1989)                | 2.7134      | YES    | 4.0
# 4     | Apartment, The (1960)                    | 3.1300      | YES    | 5.0
# 5     | Breakfast at Tiffany's (1961)            | 2.9230      | YES    | 5.0
# 6     | Doctor Zhivago (1965)                    | 2.9822      | YES    | 5.0
# 7     | Deer Hunter, The (1978)                  | 2.4131      | NO     | 2.0
# 8     | Big Night (1996)                         | 2.2898      | YES    | 5.0
# 9     | Close Encounters of the Third Kind (1977 | 1.9495      | YES    | 4.0
# 10    | Do the Right Thing (1989)                | 2.0735      | YES    | 4.0
# ================================================================================
# USER ID: 316 (Index: 315)
#   Ground truth size: 9
# Test Set Favorites (Ground Truth):
#   - Moonraker (1979) (Actual Rating: 4.0)
#   - Alien³ (1992) (Actual Rating: 4.0)
#   - 2010 (1984) (Actual Rating: 4.0)
#   - Star Trek: The Motion Picture (1979) (Actual Rating: 5.0)
#   - Lost World: Jurassic Park, The (1997) (Actual Rating: 5.0)
#   - Cube (1997) (Actual Rating: 4.0)
#   - Stepford Wives, The (1975) (Actual Rating: 4.0)
#   - Back to the Future Part III (1990) (Actual Rating: 4.0)
#   - Star Trek V: The Final Frontier (1989) (Actual Rating: 5.0)
# Model Recommendations:
# Rank  | Title                                    | Score      | Hit?   | Actual Rating
# --------------------------------------------------------------------------------
# 1     | Stepford Wives, The (1975)               | 2.3002      | YES    | 4.0
# 2     | Return of the Fly (1959)                 | 2.6671      | NO     | 3.0
# 3     | Star Trek V: The Final Frontier (1989)   | 2.1517      | YES    | 5.0
# 4     | Fly, The (1958)                          | 1.8756      | NO     | 3.0
# 5     | Star Trek: The Motion Picture (1979)     | 1.7208      | YES    | 5.0
# 6     | Alien³ (1992)                            | 1.5694      | YES    | 4.0
# 7     | Cube (1997)                              | 1.1383      | YES    | 4.0
# 8     | Conquest of the Planet of the Apes (1972 | 1.2488      | NO     | 3.0
# 9     | Back to the Future Part III (1990)       | 1.0550      | YES    | 4.0
# 10    | 2010 (1984)                              | 0.7030      | YES    | 4.0
# PPO Ablation Study Evaluation on Test Set
# Precision@5: 0.6753
# NDCG@5: 0.7147
# Precision@10: 0.5998
# NDCG@10: 0.7470
# Ablation Study 3: n=1, T_max=100
# ================================================================================
# USER ID: 1 (Index: 0)
#   Ground truth size: 9
# Test Set Favorites (Ground Truth):
#   - Beauty and the Beast (1991) (Actual Rating: 5.0)
#   - Aladdin (1992) (Actual Rating: 4.0)
#   - Toy Story (1995) (Actual Rating: 5.0)
#   - Bug's Life, A (1998) (Actual Rating: 5.0)
#   - Antz (1998) (Actual Rating: 4.0)
#   - Hunchback of Notre Dame, The (1996) (Actual Rating: 4.0)
#   - Hercules (1997) (Actual Rating: 4.0)
#   - Mulan (1998) (Actual Rating: 4.0)
#   - Pocahontas (1995) (Actual Rating: 5.0)
# Model Recommendations:
# Rank  | Title                                    | Score      | Hit?   | Actual Rating
# --------------------------------------------------------------------------------
# 1     | Beauty and the Beast (1991)              | 2.5021      | YES    | 5.0
# 2     | Toy Story (1995)                         | 2.7525      | YES    | 5.0
# 3     | Hunchback of Notre Dame, The (1996)      | 1.9675      | YES    | 4.0
# 4     | Bug's Life, A (1998)                     | 1.9640      | YES    | 5.0
# 5     | Aladdin (1992)                           | 1.9103      | YES    | 4.0
# 6     | Close Shave, A (1995)                    | 1.8729      | NO     | 3.0
# 7     | Tarzan (1999)                            | 1.5216      | NO     | 3.0
# 8     | Mulan (1998)                             | 0.5674      | YES    | 4.0
# 9     | Pocahontas (1995)                        | 0.3669      | YES    | 5.0
# 10    | Antz (1998)                              | 0.8642      | YES    | 4.0
# ================================================================================
# USER ID: 3 (Index: 2)
#   Ground truth size: 6
# Test Set Favorites (Ground Truth):
#   - Fish Called Wanda, A (1988) (Actual Rating: 5.0)
#   - Stand by Me (1986) (Actual Rating: 5.0)
#   - Bug's Life, A (1998) (Actual Rating: 5.0)
#   - Caddyshack (1980) (Actual Rating: 5.0)
#   - Happy Gilmore (1996) (Actual Rating: 4.0)
#   - Little Mermaid, The (1989) (Actual Rating: 4.0)
# Model Recommendations:
# Rank  | Title                                    | Score      | Hit?   | Actual Rating
# --------------------------------------------------------------------------------
# 1     | Caddyshack (1980)                        | 3.2696      | YES    | 5.0
# 2     | Full Monty, The (1997)                   | 2.6213      | NO     | 2.0
# 3     | Little Mermaid, The (1989)               | 2.5453      | YES    | 4.0
# 4     | Naked Gun: From the Files of Police Squa | 2.7052      | NO     | 3.0
# 5     | Stand by Me (1986)                       | 2.6151      | YES    | 5.0
# 6     | Groundhog Day (1993)                     | 2.4359      | NO     | 2.0
# 7     | Fish Called Wanda, A (1988)              | 2.1867      | YES    | 5.0
# 8     | Bug's Life, A (1998)                     | 2.1015      | YES    | 5.0
# 9     | Back to the Future (1985)                | 1.7085      | NO     | 3.0
# 10    | Happy Gilmore (1996)                     | 1.2829      | YES    | 4.0
# ================================================================================
# USER ID: 40 (Index: 39)
#   Ground truth size: 9
# Test Set Favorites (Ground Truth):
#   - Captain Horatio Hornblower (1951) (Actual Rating: 4.0)
#   - Flying Tigers (1942) (Actual Rating: 4.0)
#   - Forrest Gump (1994) (Actual Rating: 4.0)
#   - Longest Day, The (1962) (Actual Rating: 4.0)
#   - Them! (1954) (Actual Rating: 5.0)
#   - Fighting Seabees, The (1944) (Actual Rating: 4.0)
#   - Crimson Tide (1995) (Actual Rating: 4.0)
#   - Independence Day (ID4) (1996) (Actual Rating: 4.0)
#   - Hot Shots! Part Deux (1993) (Actual Rating: 4.0)
# Model Recommendations:
# Rank  | Title                                    | Score      | Hit?   | Actual Rating
# --------------------------------------------------------------------------------
# 1     | Longest Day, The (1962)                  | 3.2484      | YES    | 4.0
# 2     | Tora! Tora! Tora! (1970)                 | 3.0369      | NO     | 3.0
# 3     | Them! (1954)                             | 2.1795      | YES    | 5.0
# 4     | Flying Tigers (1942)                     | 3.0176      | YES    | 4.0
# 5     | Fighting Seabees, The (1944)             | 1.9686      | YES    | 4.0
# 6     | Forrest Gump (1994)                      | 1.9303      | YES    | 4.0
# 7     | Crimson Tide (1995)                      | 1.8285      | YES    | 4.0
# 8     | Starship Troopers (1997)                 | 1.8322      | NO     | 2.0
# 9     | Pork Chop Hill (1959)                    | 1.7391      | NO     | 3.0
# 10    | Mars Attacks! (1996)                     | 1.5590      | NO     | 3.0
# ================================================================================
# USER ID: 67 (Index: 66)
#   Ground truth size: 12
# Test Set Favorites (Ground Truth):
#   - Apollo 13 (1995) (Actual Rating: 5.0)
#   - Prizzi's Honor (1985) (Actual Rating: 4.0)
#   - Doctor Zhivago (1965) (Actual Rating: 5.0)
#   - Close Encounters of the Third Kind (1977) (Actual Rating: 4.0)
#   - Do the Right Thing (1989) (Actual Rating: 4.0)
#   - Rocky (1976) (Actual Rating: 5.0)
#   - Miracle on 34th Street (1947) (Actual Rating: 5.0)
#   - Ben-Hur (1959) (Actual Rating: 5.0)
#   - Apartment, The (1960) (Actual Rating: 5.0)
#   - Big Night (1996) (Actual Rating: 5.0)
#   - Driving Miss Daisy (1989) (Actual Rating: 4.0)
#   - Breakfast at Tiffany's (1961) (Actual Rating: 5.0)
# Model Recommendations:
# Rank  | Title                                    | Score      | Hit?   | Actual Rating
# --------------------------------------------------------------------------------
# 1     | Do the Right Thing (1989)                | 3.8366      | YES    | 4.0
# 2     | Prizzi's Honor (1985)                    | 3.5695      | YES    | 4.0
# 3     | Ben-Hur (1959)                           | 3.3256      | YES    | 5.0
# 4     | Doctor Zhivago (1965)                    | 3.5941      | YES    | 5.0
# 5     | Deer Hunter, The (1978)                  | 3.1472      | NO     | 2.0
# 6     | Breakfast at Tiffany's (1961)            | 2.4198      | YES    | 5.0
# 7     | Big Night (1996)                         | 3.0840      | YES    | 5.0
# 8     | Close Encounters of the Third Kind (1977 | 2.7233      | YES    | 4.0
# 9     | Apartment, The (1960)                    | 2.5541      | YES    | 5.0
# 10    | Driving Miss Daisy (1989)                | 2.5248      | YES    | 4.0
# ================================================================================
# USER ID: 316 (Index: 315)
#   Ground truth size: 9
# Test Set Favorites (Ground Truth):
#   - Moonraker (1979) (Actual Rating: 4.0)
#   - Alien³ (1992) (Actual Rating: 4.0)
#   - 2010 (1984) (Actual Rating: 4.0)
#   - Star Trek: The Motion Picture (1979) (Actual Rating: 5.0)
#   - Lost World: Jurassic Park, The (1997) (Actual Rating: 5.0)
#   - Cube (1997) (Actual Rating: 4.0)
#   - Stepford Wives, The (1975) (Actual Rating: 4.0)
#   - Back to the Future Part III (1990) (Actual Rating: 4.0)
#   - Star Trek V: The Final Frontier (1989) (Actual Rating: 5.0)
# Model Recommendations:
# Rank  | Title                                    | Score      | Hit?   | Actual Rating
# --------------------------------------------------------------------------------
# 1     | Parasite (1982)                          | 2.9032      | NO     | 2.0
# 2     | Cube (1997)                              | 2.1489      | YES    | 4.0
# 3     | Return of the Fly (1959)                 | 1.7549      | NO     | 3.0
# 4     | Back to the Future Part III (1990)       | 1.2339      | YES    | 4.0
# 5     | Conquest of the Planet of the Apes (1972 | 1.7438      | NO     | 3.0
# 6     | My Science Project (1985)                | 1.6892      | NO     | 3.0
# 7     | Fly, The (1958)                          | 1.1901      | NO     | 3.0
# 8     | Honey, I Shrunk the Kids (1989)          | 1.1203      | NO     | 3.0
# 9     | Star Trek: The Motion Picture (1979)     | 1.0720      | YES    | 5.0
# 10    | Lost World: Jurassic Park, The (1997)    | 0.8923      | YES    | 5.0
# PPO Ablation Study Evaluation on Test Set
# Precision@5: 0.6652
# NDCG@5: 0.7063
# Precision@10: 0.5937
# NDCG@10: 0.7408
# Ablation Study 4: n=1, T_max=500
# ================================================================================
# USER ID: 1 (Index: 0)
#   Ground truth size: 9
# Test Set Favorites (Ground Truth):
#   - Beauty and the Beast (1991) (Actual Rating: 5.0)
#   - Aladdin (1992) (Actual Rating: 4.0)
#   - Toy Story (1995) (Actual Rating: 5.0)
#   - Bug's Life, A (1998) (Actual Rating: 5.0)
#   - Antz (1998) (Actual Rating: 4.0)
#   - Hunchback of Notre Dame, The (1996) (Actual Rating: 4.0)
#   - Hercules (1997) (Actual Rating: 4.0)
#   - Mulan (1998) (Actual Rating: 4.0)
#   - Pocahontas (1995) (Actual Rating: 5.0)
# Model Recommendations:
# Rank  | Title                                    | Score      | Hit?   | Actual Rating
# --------------------------------------------------------------------------------
# 1     | Beauty and the Beast (1991)              | 3.8744      | YES    | 5.0
# 2     | Toy Story (1995)                         | 3.3863      | YES    | 5.0
# 3     | Aladdin (1992)                           | 2.6876      | YES    | 4.0
# 4     | Antz (1998)                              | 1.9475      | YES    | 4.0
# 5     | Bug's Life, A (1998)                     | 1.9530      | YES    | 5.0
# 6     | Mulan (1998)                             | 1.7826      | YES    | 4.0
# 7     | Close Shave, A (1995)                    | 1.9568      | NO     | 3.0
# 8     | Tarzan (1999)                            | 1.1350      | NO     | 3.0
# 9     | Hercules (1997)                          | 1.0510      | YES    | 4.0
# 10    | Hunchback of Notre Dame, The (1996)      | 0.6223      | YES    | 4.0
# ================================================================================
# USER ID: 3 (Index: 2)
#   Ground truth size: 6
# Test Set Favorites (Ground Truth):
#   - Fish Called Wanda, A (1988) (Actual Rating: 5.0)
#   - Stand by Me (1986) (Actual Rating: 5.0)
#   - Bug's Life, A (1998) (Actual Rating: 5.0)
#   - Caddyshack (1980) (Actual Rating: 5.0)
#   - Happy Gilmore (1996) (Actual Rating: 4.0)
#   - Little Mermaid, The (1989) (Actual Rating: 4.0)
# Model Recommendations:
# Rank  | Title                                    | Score      | Hit?   | Actual Rating
# --------------------------------------------------------------------------------
# 1     | Back to the Future (1985)                | 2.9874      | NO     | 3.0
# 2     | Stand by Me (1986)                       | 2.6529      | YES    | 5.0
# 3     | Full Monty, The (1997)                   | 2.6367      | NO     | 2.0
# 4     | Groundhog Day (1993)                     | 1.9936      | NO     | 2.0
# 5     | Caddyshack (1980)                        | 1.8023      | YES    | 5.0
# 6     | Fish Called Wanda, A (1988)              | 1.6861      | YES    | 5.0
# 7     | Bug's Life, A (1998)                     | 1.6895      | YES    | 5.0
# 8     | Little Mermaid, The (1989)               | 1.4476      | YES    | 4.0
# 9     | Happy Gilmore (1996)                     | 1.2512      | YES    | 4.0
# 10    | Naked Gun: From the Files of Police Squa | 1.2153      | NO     | 3.0
# ================================================================================
# USER ID: 40 (Index: 39)
#   Ground truth size: 9
# Test Set Favorites (Ground Truth):
#   - Captain Horatio Hornblower (1951) (Actual Rating: 4.0)
#   - Flying Tigers (1942) (Actual Rating: 4.0)
#   - Forrest Gump (1994) (Actual Rating: 4.0)
#   - Longest Day, The (1962) (Actual Rating: 4.0)
#   - Them! (1954) (Actual Rating: 5.0)
#   - Fighting Seabees, The (1944) (Actual Rating: 4.0)
#   - Crimson Tide (1995) (Actual Rating: 4.0)
#   - Independence Day (ID4) (1996) (Actual Rating: 4.0)
#   - Hot Shots! Part Deux (1993) (Actual Rating: 4.0)
# Model Recommendations:
# Rank  | Title                                    | Score      | Hit?   | Actual Rating
# --------------------------------------------------------------------------------
# 1     | Pork Chop Hill (1959)                    | 4.0774      | NO     | 3.0
# 2     | Captain Horatio Hornblower (1951)        | 3.7904      | YES    | 4.0
# 3     | Red Dawn (1984)                          | 3.2533      | NO     | 2.0
# 4     | South Pacific (1958)                     | 2.6929      | NO     | 3.0
# 5     | Force 10 from Navarone (1978)            | 2.4996      | NO     | 2.0
# 6     | Longest Day, The (1962)                  | 2.2755      | YES    | 4.0
# 7     | Them! (1954)                             | 1.9814      | YES    | 5.0
# 8     | Iron Eagle (1986)                        | 2.0794      | NO     | 1.0
# 9     | Forrest Gump (1994)                      | 1.9919      | YES    | 4.0
# 10    | Independence Day (ID4) (1996)            | 1.9831      | YES    | 4.0
# ================================================================================
# USER ID: 67 (Index: 66)
#   Ground truth size: 12
# Test Set Favorites (Ground Truth):
#   - Apollo 13 (1995) (Actual Rating: 5.0)
#   - Prizzi's Honor (1985) (Actual Rating: 4.0)
#   - Doctor Zhivago (1965) (Actual Rating: 5.0)
#   - Close Encounters of the Third Kind (1977) (Actual Rating: 4.0)
#   - Do the Right Thing (1989) (Actual Rating: 4.0)
#   - Rocky (1976) (Actual Rating: 5.0)
#   - Miracle on 34th Street (1947) (Actual Rating: 5.0)
#   - Ben-Hur (1959) (Actual Rating: 5.0)
#   - Apartment, The (1960) (Actual Rating: 5.0)
#   - Big Night (1996) (Actual Rating: 5.0)
#   - Driving Miss Daisy (1989) (Actual Rating: 4.0)
#   - Breakfast at Tiffany's (1961) (Actual Rating: 5.0)
# Model Recommendations:
# Rank  | Title                                    | Score      | Hit?   | Actual Rating
# --------------------------------------------------------------------------------
# 1     | Breakfast at Tiffany's (1961)            | 3.8428      | YES    | 5.0
# 2     | Big Night (1996)                         | 3.6339      | YES    | 5.0
# 3     | Rocky (1976)                             | 3.6398      | YES    | 5.0
# 4     | Deer Hunter, The (1978)                  | 2.9776      | NO     | 2.0
# 5     | Ben-Hur (1959)                           | 2.9364      | YES    | 5.0
# 6     | Apartment, The (1960)                    | 2.6403      | YES    | 5.0
# 7     | Do the Right Thing (1989)                | 2.6448      | YES    | 4.0
# 8     | Close Encounters of the Third Kind (1977 | 2.1351      | YES    | 4.0
# 9     | Doctor Zhivago (1965)                    | 2.3731      | YES    | 5.0
# 10    | Driving Miss Daisy (1989)                | 1.9825      | YES    | 4.0
# ================================================================================
# USER ID: 316 (Index: 315)
#   Ground truth size: 9
# Test Set Favorites (Ground Truth):
#   - Moonraker (1979) (Actual Rating: 4.0)
#   - Alien³ (1992) (Actual Rating: 4.0)
#   - 2010 (1984) (Actual Rating: 4.0)
#   - Star Trek: The Motion Picture (1979) (Actual Rating: 5.0)
#   - Lost World: Jurassic Park, The (1997) (Actual Rating: 5.0)
#   - Cube (1997) (Actual Rating: 4.0)
#   - Stepford Wives, The (1975) (Actual Rating: 4.0)
#   - Back to the Future Part III (1990) (Actual Rating: 4.0)
#   - Star Trek V: The Final Frontier (1989) (Actual Rating: 5.0)
# Model Recommendations:
# Rank  | Title                                    | Score      | Hit?   | Actual Rating
# --------------------------------------------------------------------------------
# 1     | Parasite (1982)                          | 2.3926      | NO     | 2.0
# 2     | Back to the Future Part III (1990)       | 1.7570      | YES    | 4.0
# 3     | Fly, The (1958)                          | 1.8526      | NO     | 3.0
# 4     | Stepford Wives, The (1975)               | 1.5401      | YES    | 4.0
# 5     | 2010 (1984)                              | 1.8365      | YES    | 4.0
# 6     | Honey, I Shrunk the Kids (1989)          | 0.7990      | NO     | 3.0
# 7     | My Science Project (1985)                | 0.7518      | NO     | 3.0
# 8     | Star Trek V: The Final Frontier (1989)   | 0.7091      | YES    | 5.0
# 9     | Alien³ (1992)                            | 0.2351      | YES    | 4.0
# 10    | Cube (1997)                              | -0.1962     | YES    | 4.0
# PPO Ablation Study Evaluation on Test Set
# Precision@5: 0.6732
# NDCG@5: 0.7156
# Precision@10: 0.5978
# NDCG@10: 0.7479
# Number of evaluable users: 5975
# Ablation Study 5: n=3, T_max=10
# ================================================================================
# USER ID: 1 (Index: 0)
#   Ground truth size: 9
# Test Set Favorites (Ground Truth):
#   - Beauty and the Beast (1991) (Actual Rating: 5.0)
#   - Aladdin (1992) (Actual Rating: 4.0)
#   - Toy Story (1995) (Actual Rating: 5.0)
#   - Bug's Life, A (1998) (Actual Rating: 5.0)
#   - Antz (1998) (Actual Rating: 4.0)
#   - Hunchback of Notre Dame, The (1996) (Actual Rating: 4.0)
#   - Hercules (1997) (Actual Rating: 4.0)
#   - Mulan (1998) (Actual Rating: 4.0)
#   - Pocahontas (1995) (Actual Rating: 5.0)
# Model Recommendations:
# Rank  | Title                                    | Score      | Hit?   | Actual Rating
# --------------------------------------------------------------------------------
# 1     | Antz (1998)                              | 3.0989      | YES    | 4.0
# 2     | Bug's Life, A (1998)                     | 2.8793      | YES    | 5.0
# 3     | Toy Story (1995)                         | 2.6069      | YES    | 5.0
# 4     | Aladdin (1992)                           | 2.3912      | YES    | 4.0
# 5     | Mulan (1998)                             | 2.3015      | YES    | 4.0
# 6     | Tarzan (1999)                            | 2.1674      | NO     | 3.0
# 7     | Beauty and the Beast (1991)              | 1.6261      | YES    | 5.0
# 8     | Close Shave, A (1995)                    | 1.6135      | NO     | 3.0
# 9     | Hercules (1997)                          | 1.4879      | YES    | 4.0
# 10    | Pocahontas (1995)                        | 0.6540      | YES    | 5.0
# ================================================================================
# USER ID: 3 (Index: 2)
#   Ground truth size: 6
# Test Set Favorites (Ground Truth):
#   - Fish Called Wanda, A (1988) (Actual Rating: 5.0)
#   - Stand by Me (1986) (Actual Rating: 5.0)
#   - Bug's Life, A (1998) (Actual Rating: 5.0)
#   - Caddyshack (1980) (Actual Rating: 5.0)
#   - Happy Gilmore (1996) (Actual Rating: 4.0)
#   - Little Mermaid, The (1989) (Actual Rating: 4.0)
# Model Recommendations:
# Rank  | Title                                    | Score      | Hit?   | Actual Rating
# --------------------------------------------------------------------------------
# 1     | Stand by Me (1986)                       | 3.7971      | YES    | 5.0
# 2     | Bug's Life, A (1998)                     | 2.8686      | YES    | 5.0
# 3     | Hollywood Knights, The (1980)            | 2.6577      | NO     | 2.0
# 4     | Naked Gun: From the Files of Police Squa | 2.6313      | NO     | 3.0
# 5     | Back to the Future (1985)                | 2.3732      | NO     | 3.0
# 6     | Full Monty, The (1997)                   | 2.0522      | NO     | 2.0
# 7     | Caddyshack (1980)                        | 1.9181      | YES    | 5.0
# 8     | Happy Gilmore (1996)                     | 1.8637      | YES    | 4.0
# 9     | Fish Called Wanda, A (1988)              | 1.8948      | YES    | 5.0
# 10    | Groundhog Day (1993)                     | 1.5906      | NO     | 2.0
# ================================================================================
# USER ID: 40 (Index: 39)
#   Ground truth size: 9
# Test Set Favorites (Ground Truth):
#   - Captain Horatio Hornblower (1951) (Actual Rating: 4.0)
#   - Flying Tigers (1942) (Actual Rating: 4.0)
#   - Forrest Gump (1994) (Actual Rating: 4.0)
#   - Longest Day, The (1962) (Actual Rating: 4.0)
#   - Them! (1954) (Actual Rating: 5.0)
#   - Fighting Seabees, The (1944) (Actual Rating: 4.0)
#   - Crimson Tide (1995) (Actual Rating: 4.0)
#   - Independence Day (ID4) (1996) (Actual Rating: 4.0)
#   - Hot Shots! Part Deux (1993) (Actual Rating: 4.0)
# Model Recommendations:
# Rank  | Title                                    | Score      | Hit?   | Actual Rating
# --------------------------------------------------------------------------------
# 1     | Pork Chop Hill (1959)                    | 3.3989      | NO     | 3.0
# 2     | Crimson Tide (1995)                      | 2.2608      | YES    | 4.0
# 3     | Independence Day (ID4) (1996)            | 2.0553      | YES    | 4.0
# 4     | Forrest Gump (1994)                      | 1.9414      | YES    | 4.0
# 5     | Longest Day, The (1962)                  | 1.6737      | YES    | 4.0
# 6     | Captain Horatio Hornblower (1951)        | 1.5644      | YES    | 4.0
# 7     | Hot Shots! Part Deux (1993)              | 1.6023      | YES    | 4.0
# 8     | South Pacific (1958)                     | 1.1916      | NO     | 3.0
# 9     | Mars Attacks! (1996)                     | 1.1753      | NO     | 3.0
# 10    | Them! (1954)                             | 0.9830      | YES    | 5.0
# ================================================================================
# USER ID: 67 (Index: 66)
#   Ground truth size: 12
# Test Set Favorites (Ground Truth):
#   - Apollo 13 (1995) (Actual Rating: 5.0)
#   - Prizzi's Honor (1985) (Actual Rating: 4.0)
#   - Doctor Zhivago (1965) (Actual Rating: 5.0)
#   - Close Encounters of the Third Kind (1977) (Actual Rating: 4.0)
#   - Do the Right Thing (1989) (Actual Rating: 4.0)
#   - Rocky (1976) (Actual Rating: 5.0)
#   - Miracle on 34th Street (1947) (Actual Rating: 5.0)
#   - Ben-Hur (1959) (Actual Rating: 5.0)
#   - Apartment, The (1960) (Actual Rating: 5.0)
#   - Big Night (1996) (Actual Rating: 5.0)
#   - Driving Miss Daisy (1989) (Actual Rating: 4.0)
#   - Breakfast at Tiffany's (1961) (Actual Rating: 5.0)
# Model Recommendations:
# Rank  | Title                                    | Score      | Hit?   | Actual Rating
# --------------------------------------------------------------------------------
# 1     | Prizzi's Honor (1985)                    | 3.7843      | YES    | 4.0
# 2     | Driving Miss Daisy (1989)                | 3.5690      | YES    | 4.0
# 3     | Rocky (1976)                             | 3.1683      | YES    | 5.0
# 4     | Apartment, The (1960)                    | 2.8953      | YES    | 5.0
# 5     | Doctor Zhivago (1965)                    | 2.6969      | YES    | 5.0
# 6     | Breakfast at Tiffany's (1961)            | 2.7270      | YES    | 5.0
# 7     | Apollo 13 (1995)                         | 2.4233      | YES    | 5.0
# 8     | Miracle on 34th Street (1947)            | 2.2690      | YES    | 5.0
# 9     | Close Encounters of the Third Kind (1977 | 2.1805      | YES    | 4.0
# 10    | Do the Right Thing (1989)                | 2.3101      | YES    | 4.0
# ================================================================================
# USER ID: 316 (Index: 315)
#   Ground truth size: 9
# Test Set Favorites (Ground Truth):
#   - Moonraker (1979) (Actual Rating: 4.0)
#   - Alien³ (1992) (Actual Rating: 4.0)
#   - 2010 (1984) (Actual Rating: 4.0)
#   - Star Trek: The Motion Picture (1979) (Actual Rating: 5.0)
#   - Lost World: Jurassic Park, The (1997) (Actual Rating: 5.0)
#   - Cube (1997) (Actual Rating: 4.0)
#   - Stepford Wives, The (1975) (Actual Rating: 4.0)
#   - Back to the Future Part III (1990) (Actual Rating: 4.0)
#   - Star Trek V: The Final Frontier (1989) (Actual Rating: 5.0)
# Model Recommendations:
# Rank  | Title                                    | Score      | Hit?   | Actual Rating
# --------------------------------------------------------------------------------
# 1     | Stepford Wives, The (1975)               | 2.4953      | YES    | 4.0
# 2     | Fly, The (1958)                          | 2.3405      | NO     | 3.0
# 3     | 2010 (1984)                              | 1.7493      | YES    | 4.0
# 4     | Alien³ (1992)                            | 1.5341      | YES    | 4.0
# 5     | Cube (1997)                              | 1.3034      | YES    | 4.0
# 6     | Star Trek: The Motion Picture (1979)     | 1.0339      | YES    | 5.0
# 7     | Parasite (1982)                          | 0.7073      | NO     | 2.0
# 8     | Star Trek V: The Final Frontier (1989)   | 0.6401      | YES    | 5.0
# 9     | Return of the Fly (1959)                 | 0.7149      | NO     | 3.0
# 10    | Conquest of the Planet of the Apes (1972 | 0.4789      | NO     | 3.0
# PPO Ablation Study Evaluation on Test Set
# Precision@5: 0.6850
# NDCG@5: 0.7287
# Precision@10: 0.6019
# NDCG@10: 0.7562
# Ablation Study 6: n=3, T_max=50
# ================================================================================
# USER ID: 1 (Index: 0)
#   Ground truth size: 9
# Test Set Favorites (Ground Truth):
#   - Beauty and the Beast (1991) (Actual Rating: 5.0)
#   - Aladdin (1992) (Actual Rating: 4.0)
#   - Toy Story (1995) (Actual Rating: 5.0)
#   - Bug's Life, A (1998) (Actual Rating: 5.0)
#   - Antz (1998) (Actual Rating: 4.0)
#   - Hunchback of Notre Dame, The (1996) (Actual Rating: 4.0)
#   - Hercules (1997) (Actual Rating: 4.0)
#   - Mulan (1998) (Actual Rating: 4.0)
#   - Pocahontas (1995) (Actual Rating: 5.0)
# Model Recommendations:
# Rank  | Title                                    | Score      | Hit?   | Actual Rating
# --------------------------------------------------------------------------------
# 1     | Close Shave, A (1995)                    | 2.9566      | NO     | 3.0
# 2     | Antz (1998)                              | 2.5931      | YES    | 4.0
# 3     | Bug's Life, A (1998)                     | 2.5494      | YES    | 5.0
# 4     | Aladdin (1992)                           | 2.1136      | YES    | 4.0
# 5     | Beauty and the Beast (1991)              | 2.0842      | YES    | 5.0
# 6     | Toy Story (1995)                         | 1.8648      | YES    | 5.0
# 7     | Mulan (1998)                             | 1.4921      | YES    | 4.0
# 8     | Tarzan (1999)                            | 0.6282      | NO     | 3.0
# 9     | Hercules (1997)                          | 0.3786      | YES    | 4.0
# 10    | Hunchback of Notre Dame, The (1996)      | -0.4912     | YES    | 4.0
# ================================================================================
# USER ID: 3 (Index: 2)
#   Ground truth size: 6
# Test Set Favorites (Ground Truth):
#   - Fish Called Wanda, A (1988) (Actual Rating: 5.0)
#   - Stand by Me (1986) (Actual Rating: 5.0)
#   - Bug's Life, A (1998) (Actual Rating: 5.0)
#   - Caddyshack (1980) (Actual Rating: 5.0)
#   - Happy Gilmore (1996) (Actual Rating: 4.0)
#   - Little Mermaid, The (1989) (Actual Rating: 4.0)
# Model Recommendations:
# Rank  | Title                                    | Score      | Hit?   | Actual Rating
# --------------------------------------------------------------------------------
# 1     | Hollywood Knights, The (1980)            | 3.2665      | NO     | 2.0
# 2     | Stand by Me (1986)                       | 3.2523      | YES    | 5.0
# 3     | Groundhog Day (1993)                     | 2.6985      | NO     | 2.0
# 4     | Back to the Future (1985)                | 2.6176      | NO     | 3.0
# 5     | Caddyshack (1980)                        | 2.1184      | YES    | 5.0
# 6     | Happy Gilmore (1996)                     | 1.6582      | YES    | 4.0
# 7     | Bug's Life, A (1998)                     | 1.5176      | YES    | 5.0
# 8     | Naked Gun: From the Files of Police Squa | 1.3953      | NO     | 3.0
# 9     | Little Mermaid, The (1989)               | 1.1910      | YES    | 4.0
# 10    | Fish Called Wanda, A (1988)              | 0.9675      | YES    | 5.0
# ================================================================================
# USER ID: 40 (Index: 39)
#   Ground truth size: 9
# Test Set Favorites (Ground Truth):
#   - Captain Horatio Hornblower (1951) (Actual Rating: 4.0)
#   - Flying Tigers (1942) (Actual Rating: 4.0)
#   - Forrest Gump (1994) (Actual Rating: 4.0)
#   - Longest Day, The (1962) (Actual Rating: 4.0)
#   - Them! (1954) (Actual Rating: 5.0)
#   - Fighting Seabees, The (1944) (Actual Rating: 4.0)
#   - Crimson Tide (1995) (Actual Rating: 4.0)
#   - Independence Day (ID4) (1996) (Actual Rating: 4.0)
#   - Hot Shots! Part Deux (1993) (Actual Rating: 4.0)
# Model Recommendations:
# Rank  | Title                                    | Score      | Hit?   | Actual Rating
# --------------------------------------------------------------------------------
# 1     | Flying Tigers (1942)                     | 3.3834      | YES    | 4.0
# 2     | Pork Chop Hill (1959)                    | 2.9786      | NO     | 3.0
# 3     | Longest Day, The (1962)                  | 2.8388      | YES    | 4.0
# 4     | Forrest Gump (1994)                      | 2.1474      | YES    | 4.0
# 5     | Them! (1954)                             | 2.2991      | YES    | 5.0
# 6     | Independence Day (ID4) (1996)            | 1.7185      | YES    | 4.0
# 7     | South Pacific (1958)                     | 1.6277      | NO     | 3.0
# 8     | Rambo: First Blood Part II (1985)        | 1.6106      | NO     | 2.0
# 9     | Hot Shots! Part Deux (1993)              | 1.5416      | YES    | 4.0
# 10    | Fighting Seabees, The (1944)             | 1.6585      | YES    | 4.0
# ================================================================================
# USER ID: 67 (Index: 66)
#   Ground truth size: 12
# Test Set Favorites (Ground Truth):
#   - Apollo 13 (1995) (Actual Rating: 5.0)
#   - Prizzi's Honor (1985) (Actual Rating: 4.0)
#   - Doctor Zhivago (1965) (Actual Rating: 5.0)
#   - Close Encounters of the Third Kind (1977) (Actual Rating: 4.0)
#   - Do the Right Thing (1989) (Actual Rating: 4.0)
#   - Rocky (1976) (Actual Rating: 5.0)
#   - Miracle on 34th Street (1947) (Actual Rating: 5.0)
#   - Ben-Hur (1959) (Actual Rating: 5.0)
#   - Apartment, The (1960) (Actual Rating: 5.0)
#   - Big Night (1996) (Actual Rating: 5.0)
#   - Driving Miss Daisy (1989) (Actual Rating: 4.0)
#   - Breakfast at Tiffany's (1961) (Actual Rating: 5.0)
# Model Recommendations:
# Rank  | Title                                    | Score      | Hit?   | Actual Rating
# --------------------------------------------------------------------------------
# 1     | Ben-Hur (1959)                           | 3.6662      | YES    | 5.0
# 2     | Rocky (1976)                             | 3.4188      | YES    | 5.0
# 3     | Apartment, The (1960)                    | 3.2679      | YES    | 5.0
# 4     | Do the Right Thing (1989)                | 3.0558      | YES    | 4.0
# 5     | Driving Miss Daisy (1989)                | 2.3143      | YES    | 4.0
# 6     | Doctor Zhivago (1965)                    | 2.2185      | YES    | 5.0
# 7     | Deer Hunter, The (1978)                  | 2.1303      | NO     | 2.0
# 8     | Close Encounters of the Third Kind (1977 | 1.7614      | YES    | 4.0
# 9     | Prizzi's Honor (1985)                    | 1.1913      | YES    | 4.0
# 10    | Miracle on 34th Street (1947)            | 1.2635      | YES    | 5.0
# ================================================================================
# USER ID: 316 (Index: 315)
#   Ground truth size: 9
# Test Set Favorites (Ground Truth):
#   - Moonraker (1979) (Actual Rating: 4.0)
#   - Alien³ (1992) (Actual Rating: 4.0)
#   - 2010 (1984) (Actual Rating: 4.0)
#   - Star Trek: The Motion Picture (1979) (Actual Rating: 5.0)
#   - Lost World: Jurassic Park, The (1997) (Actual Rating: 5.0)
#   - Cube (1997) (Actual Rating: 4.0)
#   - Stepford Wives, The (1975) (Actual Rating: 4.0)
#   - Back to the Future Part III (1990) (Actual Rating: 4.0)
#   - Star Trek V: The Final Frontier (1989) (Actual Rating: 5.0)
# Model Recommendations:
# Rank  | Title                                    | Score      | Hit?   | Actual Rating
# --------------------------------------------------------------------------------
# ...
#   - Toy Story (1995) (Actual Rating: 5.0)
#   - Bug's Life, A (1998) (Actual Rating: 5.0)
#   - Antz (1998) (Actual Rating: 4.0)
#   - Hunchback of Notre Dame, The (1996) (Actual Rating: 4.0)
#   - Hercules (1997) (Actual Rating: 4.0)
#   - Mulan (1998) (Actual Rating: 4.0)
#   - Pocahontas (1995) (Actual Rating: 5.0)
# Model Recommendations:
# Rank  | Title                                    | Score      | Hit?   | Actual Rating
# --------------------------------------------------------------------------------
# 1     | Toy Story (1995)                         | 2.8761      | YES    | 5.0
# 2     | Aladdin (1992)                           | 2.8555      | YES    | 4.0
# 3     | Tarzan (1999)                            | 2.4278      | NO     | 3.0
# 4     | Antz (1998)                              | 2.2393      | YES    | 4.0
# 5     | Beauty and the Beast (1991)              | 2.1001      | YES    | 5.0
# 6     | Close Shave, A (1995)                    | 1.6891      | NO     | 3.0
# 7     | Hunchback of Notre Dame, The (1996)      | 1.5968      | YES    | 4.0
# 8     | Bug's Life, A (1998)                     | 1.5011      | YES    | 5.0
# 9     | Mulan (1998)                             | 1.1961      | YES    | 4.0
# 10    | Hercules (1997)                          | 0.3844      | YES    | 4.0
# ================================================================================
# USER ID: 3 (Index: 2)
#   Ground truth size: 6
# Test Set Favorites (Ground Truth):
#   - Fish Called Wanda, A (1988) (Actual Rating: 5.0)
#   - Stand by Me (1986) (Actual Rating: 5.0)
#   - Bug's Life, A (1998) (Actual Rating: 5.0)
#   - Caddyshack (1980) (Actual Rating: 5.0)
#   - Happy Gilmore (1996) (Actual Rating: 4.0)
#   - Little Mermaid, The (1989) (Actual Rating: 4.0)
# Model Recommendations:
# Rank  | Title                                    | Score      | Hit?   | Actual Rating
# --------------------------------------------------------------------------------
# 1     | Little Mermaid, The (1989)               | 2.5043      | YES    | 4.0
# 2     | Naked Gun: From the Files of Police Squa | 1.5615      | NO     | 3.0
# 3     | Full Monty, The (1997)                   | 1.5306      | NO     | 2.0
# 4     | Back to the Future (1985)                | 1.3896      | NO     | 3.0
# 5     | Groundhog Day (1993)                     | 1.2884      | NO     | 2.0
# 6     | Bug's Life, A (1998)                     | 1.2707      | YES    | 5.0
# 7     | Happy Gilmore (1996)                     | 1.2359      | YES    | 4.0
# 8     | Stand by Me (1986)                       | 0.8129      | YES    | 5.0
# 9     | Fish Called Wanda, A (1988)              | 0.8101      | YES    | 5.0
# 10    | Caddyshack (1980)                        | 0.6894      | YES    | 5.0
# ================================================================================
# USER ID: 40 (Index: 39)
#   Ground truth size: 9
# Test Set Favorites (Ground Truth):
#   - Captain Horatio Hornblower (1951) (Actual Rating: 4.0)
#   - Flying Tigers (1942) (Actual Rating: 4.0)
#   - Forrest Gump (1994) (Actual Rating: 4.0)
#   - Longest Day, The (1962) (Actual Rating: 4.0)
#   - Them! (1954) (Actual Rating: 5.0)
#   - Fighting Seabees, The (1944) (Actual Rating: 4.0)
#   - Crimson Tide (1995) (Actual Rating: 4.0)
#   - Independence Day (ID4) (1996) (Actual Rating: 4.0)
#   - Hot Shots! Part Deux (1993) (Actual Rating: 4.0)
# Model Recommendations:
# Rank  | Title                                    | Score      | Hit?   | Actual Rating
# --------------------------------------------------------------------------------
# 1     | Captain Horatio Hornblower (1951)        | 2.2804      | YES    | 4.0
# 2     | Them! (1954)                             | 2.2455      | YES    | 5.0
# 3     | Longest Day, The (1962)                  | 2.0659      | YES    | 4.0
# 4     | Pork Chop Hill (1959)                    | 2.0238      | NO     | 3.0
# 5     | Flying Tigers (1942)                     | 1.9268      | YES    | 4.0
# 6     | Independence Day (ID4) (1996)            | 1.8981      | YES    | 4.0
# 7     | Crimson Tide (1995)                      | 1.8736      | YES    | 4.0
# 8     | South Pacific (1958)                     | 1.7889      | NO     | 3.0
# 9     | Forrest Gump (1994)                      | 1.4431      | YES    | 4.0
# 10    | Hot Shots! Part Deux (1993)              | 1.3666      | YES    | 4.0
# ================================================================================
# USER ID: 67 (Index: 66)
#   Ground truth size: 12
# Test Set Favorites (Ground Truth):
#   - Apollo 13 (1995) (Actual Rating: 5.0)
#   - Prizzi's Honor (1985) (Actual Rating: 4.0)
#   - Doctor Zhivago (1965) (Actual Rating: 5.0)
#   - Close Encounters of the Third Kind (1977) (Actual Rating: 4.0)
#   - Do the Right Thing (1989) (Actual Rating: 4.0)
#   - Rocky (1976) (Actual Rating: 5.0)
#   - Miracle on 34th Street (1947) (Actual Rating: 5.0)
#   - Ben-Hur (1959) (Actual Rating: 5.0)
#   - Apartment, The (1960) (Actual Rating: 5.0)
#   - Big Night (1996) (Actual Rating: 5.0)
#   - Driving Miss Daisy (1989) (Actual Rating: 4.0)
#   - Breakfast at Tiffany's (1961) (Actual Rating: 5.0)
# Model Recommendations:
# Rank  | Title                                    | Score      | Hit?   | Actual Rating
# --------------------------------------------------------------------------------
# 1     | Do the Right Thing (1989)                | 3.3009      | YES    | 4.0
# 2     | Deer Hunter, The (1978)                  | 3.2678      | NO     | 2.0
# 3     | Ben-Hur (1959)                           | 3.1925      | YES    | 5.0
# 4     | Rocky (1976)                             | 3.0135      | YES    | 5.0
# 5     | Doctor Zhivago (1965)                    | 2.2449      | YES    | 5.0
# 6     | Breakfast at Tiffany's (1961)            | 2.1652      | YES    | 5.0
# 7     | Close Encounters of the Third Kind (1977 | 2.1325      | YES    | 4.0
# 8     | Apartment, The (1960)                    | 2.0477      | YES    | 5.0
# 9     | Prizzi's Honor (1985)                    | 2.0018      | YES    | 4.0
# 10    | Driving Miss Daisy (1989)                | 1.8715      | YES    | 4.0
# ================================================================================
# USER ID: 316 (Index: 315)
#   Ground truth size: 9
# Test Set Favorites (Ground Truth):
#   - Moonraker (1979) (Actual Rating: 4.0)
#   - Alien³ (1992) (Actual Rating: 4.0)
#   - 2010 (1984) (Actual Rating: 4.0)
#   - Star Trek: The Motion Picture (1979) (Actual Rating: 5.0)
#   - Lost World: Jurassic Park, The (1997) (Actual Rating: 5.0)
#   - Cube (1997) (Actual Rating: 4.0)
#   - Stepford Wives, The (1975) (Actual Rating: 4.0)
#   - Back to the Future Part III (1990) (Actual Rating: 4.0)
#   - Star Trek V: The Final Frontier (1989) (Actual Rating: 5.0)
# Model Recommendations:
# Rank  | Title                                    | Score      | Hit?   | Actual Rating
# --------------------------------------------------------------------------------
# 1     | Parasite (1982)                          | 2.4875      | NO     | 2.0
# 2     | Cube (1997)                              | 1.9842      | YES    | 4.0
# 3     | Moonraker (1979)                         | 1.7084      | YES    | 4.0
# 4     | Fly, The (1958)                          | 1.6625      | NO     | 3.0
# 5     | Star Trek: The Motion Picture (1979)     | 1.5956      | YES    | 5.0
# 6     | Star Trek V: The Final Frontier (1989)   | 1.1178      | YES    | 5.0
# 7     | Stepford Wives, The (1975)               | 0.9812      | YES    | 4.0
# 8     | Return of the Fly (1959)                 | 0.6976      | NO     | 3.0
# 9     | 2010 (1984)                              | 0.6448      | YES    | 4.0
# 10    | Alien³ (1992)                            | 0.4305      | YES    | 4.0
# PPO Ablation Study Evaluation on Test Set
# Precision@5: 0.6813
# NDCG@5: 0.7172
# Precision@10: 0.6091
# NDCG@10: 0.7480
# Ablation Study 20: n=10, T_max=500
# ================================================================================
# USER ID: 1 (Index: 0)
#   Ground truth size: 9
# Test Set Favorites (Ground Truth):
#   - Beauty and the Beast (1991) (Actual Rating: 5.0)
#   - Aladdin (1992) (Actual Rating: 4.0)
#   - Toy Story (1995) (Actual Rating: 5.0)
#   - Bug's Life, A (1998) (Actual Rating: 5.0)
#   - Antz (1998) (Actual Rating: 4.0)
#   - Hunchback of Notre Dame, The (1996) (Actual Rating: 4.0)
#   - Hercules (1997) (Actual Rating: 4.0)
#   - Mulan (1998) (Actual Rating: 4.0)
#   - Pocahontas (1995) (Actual Rating: 5.0)
# Model Recommendations:
# Rank  | Title                                    | Score      | Hit?   | Actual Rating
# --------------------------------------------------------------------------------
# 1     | Beauty and the Beast (1991)              | 3.0774      | YES    | 5.0
# 2     | Close Shave, A (1995)                    | 2.8275      | NO     | 3.0
# 3     | Toy Story (1995)                         | 2.7709      | YES    | 5.0
# 4     | Bug's Life, A (1998)                     | 2.5521      | YES    | 5.0
# 5     | Antz (1998)                              | 2.4924      | YES    | 4.0
# 6     | Mulan (1998)                             | 2.1618      | YES    | 4.0
# 7     | Tarzan (1999)                            | 1.6248      | NO     | 3.0
# 8     | Aladdin (1992)                           | 1.4727      | YES    | 4.0
# 9     | Hercules (1997)                          | 1.3231      | YES    | 4.0
# 10    | Hunchback of Notre Dame, The (1996)      | 0.8034      | YES    | 4.0
# ================================================================================
# USER ID: 3 (Index: 2)
#   Ground truth size: 6
# Test Set Favorites (Ground Truth):
#   - Fish Called Wanda, A (1988) (Actual Rating: 5.0)
#   - Stand by Me (1986) (Actual Rating: 5.0)
#   - Bug's Life, A (1998) (Actual Rating: 5.0)
#   - Caddyshack (1980) (Actual Rating: 5.0)
#   - Happy Gilmore (1996) (Actual Rating: 4.0)
#   - Little Mermaid, The (1989) (Actual Rating: 4.0)
# Model Recommendations:
# Rank  | Title                                    | Score      | Hit?   | Actual Rating
# --------------------------------------------------------------------------------
# 1     | Caddyshack (1980)                        | 3.5264      | YES    | 5.0
# 2     | Bug's Life, A (1998)                     | 2.5351      | YES    | 5.0
# 3     | Hollywood Knights, The (1980)            | 2.5445      | NO     | 2.0
# 4     | Little Mermaid, The (1989)               | 2.4087      | YES    | 4.0
# 5     | Fish Called Wanda, A (1988)              | 2.1294      | YES    | 5.0
# 6     | Groundhog Day (1993)                     | 2.0361      | NO     | 2.0
# 7     | Full Monty, The (1997)                   | 1.7836      | NO     | 2.0
# 8     | Back to the Future (1985)                | 1.7546      | NO     | 3.0
# 9     | Naked Gun: From the Files of Police Squa | 1.4337      | NO     | 3.0
# 10    | Stand by Me (1986)                       | 0.6254      | YES    | 5.0
# ================================================================================
# USER ID: 40 (Index: 39)
#   Ground truth size: 9
# Test Set Favorites (Ground Truth):
#   - Captain Horatio Hornblower (1951) (Actual Rating: 4.0)
#   - Flying Tigers (1942) (Actual Rating: 4.0)
#   - Forrest Gump (1994) (Actual Rating: 4.0)
#   - Longest Day, The (1962) (Actual Rating: 4.0)
#   - Them! (1954) (Actual Rating: 5.0)
#   - Fighting Seabees, The (1944) (Actual Rating: 4.0)
#   - Crimson Tide (1995) (Actual Rating: 4.0)
#   - Independence Day (ID4) (1996) (Actual Rating: 4.0)
#   - Hot Shots! Part Deux (1993) (Actual Rating: 4.0)
# Model Recommendations:
# Rank  | Title                                    | Score      | Hit?   | Actual Rating
# --------------------------------------------------------------------------------
# 1     | Red Dawn (1984)                          | 3.0271      | NO     | 2.0
# 2     | Pork Chop Hill (1959)                    | 2.8571      | NO     | 3.0
# 3     | Independence Day (ID4) (1996)            | 2.6129      | YES    | 4.0
# 4     | Captain Horatio Hornblower (1951)        | 2.5343      | YES    | 4.0
# 5     | Iron Eagle II (1988)                     | 2.3081      | NO     | 1.0
# 6     | Mars Attacks! (1996)                     | 2.0391      | NO     | 3.0
# 7     | Them! (1954)                             | 1.9629      | YES    | 5.0
# 8     | Fighting Seabees, The (1944)             | 1.6565      | YES    | 4.0
# 9     | Longest Day, The (1962)                  | 1.4777      | YES    | 4.0
# 10    | South Pacific (1958)                     | 1.4641      | NO     | 3.0
# ================================================================================
# USER ID: 67 (Index: 66)
#   Ground truth size: 12
# Test Set Favorites (Ground Truth):
#   - Apollo 13 (1995) (Actual Rating: 5.0)
#   - Prizzi's Honor (1985) (Actual Rating: 4.0)
#   - Doctor Zhivago (1965) (Actual Rating: 5.0)
#   - Close Encounters of the Third Kind (1977) (Actual Rating: 4.0)
#   - Do the Right Thing (1989) (Actual Rating: 4.0)
#   - Rocky (1976) (Actual Rating: 5.0)
#   - Miracle on 34th Street (1947) (Actual Rating: 5.0)
#   - Ben-Hur (1959) (Actual Rating: 5.0)
#   - Apartment, The (1960) (Actual Rating: 5.0)
#   - Big Night (1996) (Actual Rating: 5.0)
#   - Driving Miss Daisy (1989) (Actual Rating: 4.0)
#   - Breakfast at Tiffany's (1961) (Actual Rating: 5.0)
# Model Recommendations:
# Rank  | Title                                    | Score      | Hit?   | Actual Rating
# --------------------------------------------------------------------------------
# 1     | Apartment, The (1960)                    | 3.8026      | YES    | 5.0
# 2     | Rocky (1976)                             | 3.6075      | YES    | 5.0
# 3     | Ben-Hur (1959)                           | 3.5706      | YES    | 5.0
# 4     | Prizzi's Honor (1985)                    | 3.5781      | YES    | 4.0
# 5     | Do the Right Thing (1989)                | 3.3034      | YES    | 4.0
# 6     | Doctor Zhivago (1965)                    | 3.0030      | YES    | 5.0
# 7     | Big Night (1996)                         | 2.8573      | YES    | 5.0
# 8     | Apollo 13 (1995)                         | 2.3166      | YES    | 5.0
# 9     | Deer Hunter, The (1978)                  | 1.8403      | NO     | 2.0
# 10    | Close Encounters of the Third Kind (1977 | 0.8791      | YES    | 4.0
# ================================================================================
# USER ID: 316 (Index: 315)
#   Ground truth size: 9
# Test Set Favorites (Ground Truth):
#   - Moonraker (1979) (Actual Rating: 4.0)
#   - Alien³ (1992) (Actual Rating: 4.0)
#   - 2010 (1984) (Actual Rating: 4.0)
#   - Star Trek: The Motion Picture (1979) (Actual Rating: 5.0)
#   - Lost World: Jurassic Park, The (1997) (Actual Rating: 5.0)
#   - Cube (1997) (Actual Rating: 4.0)
#   - Stepford Wives, The (1975) (Actual Rating: 4.0)
#   - Back to the Future Part III (1990) (Actual Rating: 4.0)
#   - Star Trek V: The Final Frontier (1989) (Actual Rating: 5.0)
# Model Recommendations:
# Rank  | Title                                    | Score      | Hit?   | Actual Rating
# --------------------------------------------------------------------------------
# 1     | Parasite (1982)                          | 3.9428      | NO     | 2.0
# 2     | Fly, The (1958)                          | 2.4441      | NO     | 3.0
# 3     | Cube (1997)                              | 1.9244      | YES    | 4.0
# 4     | Back to the Future Part III (1990)       | 1.6480      | YES    | 4.0
# 5     | Star Trek: The Motion Picture (1979)     | 1.0927      | YES    | 5.0
# 6     | Honey, I Shrunk the Kids (1989)          | 0.5358      | NO     | 3.0
# 7     | Moonraker (1979)                         | 0.4173      | YES    | 4.0
# 8     | Conquest of the Planet of the Apes (1972 | 0.1104      | NO     | 3.0
# 9     | Lawnmower Man, The (1992)                | 0.0139      | NO     | 3.0
# 10    | Stepford Wives, The (1975)               | 0.0097      | YES    | 4.0
# PPO Ablation Study Evaluation on Test Set
# Precision@5: 0.6773
# NDCG@5: 0.7109
# Precision@10: 0.6058
# NDCG@10: 0.7429

# %%
print("Done!")
# Out:
# Done!

# %%
all_Ab_study_eval_results
# Out:
# {1: {'n_history': 1,
#   'T_max': 10,
#   'Precision@5': 0.6882343096234309,
#   'NDCG@5': 0.7333096726453657,
#   'Precision@10': 0.6072635983263599,
#   'NDCG@10': 0.7615999084534475},
#  2: {'n_history': 1,
#   'T_max': 50,
#   'Precision@5': 0.6752803347280335,
#   'NDCG@5': 0.7147023634014746,
#   'Precision@10': 0.5998493723849373,
#   'NDCG@10': 0.7469747475391463},
#  3: {'n_history': 1,
#   'T_max': 100,
#   'Precision@5': 0.6652384937238494,
#   'NDCG@5': 0.7062748593792979,
#   'Precision@10': 0.5937405857740586,
#   'NDCG@10': 0.7408439369901353},
#  4: {'n_history': 1,
#   'T_max': 500,
#   'Precision@5': 0.6732384937238494,
#   'NDCG@5': 0.7156244855595488,
#   'Precision@10': 0.5977740585774058,
#   'NDCG@10': 0.7478531964491977},
#  5: {'n_history': 3,
#   'T_max': 10,
#   'Precision@5': 0.6850209205020921,
#   'NDCG@5': 0.7287425544471707,
#   'Precision@10': 0.6018577405857741,
#   'NDCG@10': 0.7561858680972547},
#  6: {'n_history': 3,
#   'T_max': 50,
#   'Precision@5': 0.6796652719665272,
#   'NDCG@5': 0.7219547269172222,
#   'Precision@10': 0.6000502092050208,
#   'NDCG@10': 0.7513122991538483},
#  7: {'n_history': 3,
#   'T_max': 100,
#   'Precision@5': 0.6645020920502093,
#   'NDCG@5': 0.7029169640483907,
#   'Precision@10': 0.5928535564853556,
#   'NDCG@10': 0.7381298925269381},
#  8: {'n_history': 3,
#   'T_max': 500,
#   'Precision@5': 0.6779581589958159,
#   'NDCG@5': 0.718759879296677,
#   'Precision@10': 0.599531380753138,
#   'NDCG@10': 0.7493359746604121},
#  9: {'n_history': 5,
#   'T_max': 10,
#   'Precision@5': 0.6829391041771515,
#   'NDCG@5': 0.727294718370365,
#   'Precision@10': 0.6017278980036906,
#   'NDCG@10': 0.7554238233771303},
#  10: {'n_history': 5,
#   'T_max': 50,
#   'Precision@5': 0.6819996644858245,
#   'NDCG@5': 0.7244742164770337,
#   'Precision@10': 0.6034390202986076,
#   'NDCG@10': 0.7545431177268654},
#  11: {'n_history': 5,
#   'T_max': 100,
#   'Precision@5': 0.6733433987585975,
#   'NDCG@5': 0.7161370434786009,
#   'Precision@10': 0.5954873343398759,
#   'NDCG@10': 0.7464021083240479},
#  12: {'n_history': 5,
#   'T_max': 500,
#   'Precision@5': 0.6770005032712632,
#   'NDCG@5': 0.7172905663704486,
#   'Precision@10': 0.6005032712632109,
#   'NDCG@10': 0.7493330542838076},
#  13: {'n_history': 7,
#   'T_max': 10,
#   'Precision@5': 0.6826446280991736,
#   'NDCG@5': 0.7235161615462559,
#   'Precision@10': 0.6027660651037274,
#   'NDCG@10': 0.7522129756413394},
#  14: {'n_history': 7,
#   'T_max': 50,
#   'Precision@5': 0.6785292629448474,
#   'NDCG@5': 0.7183912530815347,
#   'Precision@10': 0.6025974025974026,
#   'NDCG@10': 0.7497408357768501},
#  15: {'n_history': 7,
#   'T_max': 100,
#   'Precision@5': 0.6686119075729465,
#   'NDCG@5': 0.7063649270279416,
#   'Precision@10': 0.5956485073368191,
#   'NDCG@10': 0.7392472004178812},
#  16: {'n_history': 7,
#   'T_max': 500,
#   'Precision@5': 0.6719176926969135,
#   'NDCG@5': 0.7117981610082522,
#   'Precision@10': 0.59741946365323,
#   'NDCG@10': 0.7440868166536612},
#  17: {'n_history': 10,
#   'T_max': 10,
#   'Precision@5': 0.6898100172711572,
#   'NDCG@5': 0.7237919170963318,
#   'Precision@10': 0.6128842832469775,
#   'NDCG@10': 0.7524003528211328},
#  18: {'n_history': 10,
#   'T_max': 50,
#   'Precision@5': 0.6799999999999999,
#   'NDCG@5': 0.7143118951079953,
#   'Precision@10': 0.6083592400690846,
#   'NDCG@10': 0.7457824337218742},
#  19: {'n_history': 10,
#   'T_max': 100,
#   'Precision@5': 0.6813471502590673,
#   'NDCG@5': 0.7171738681015088,
#   'Precision@10': 0.6090673575129534,
#   'NDCG@10': 0.7479908994942465},
#  20: {'n_history': 10,
#   'T_max': 500,
#   'Precision@5': 0.6772711571675302,
#   'NDCG@5': 0.710915244562406,
#   'Precision@10': 0.6058203799654577,
#   'NDCG@10': 0.7428767852485659}}

# %%
with open('../results/PPO_ablation_study_results.pkl', 'wb') as f:
    pickle.dump(all_Ab_study_eval_results, f)

# %% [markdown]
# # Print Ablation Study IDs of the best and worst metrics and each Study's metrics

# %%
best = {}
worst = {}

metrics = ["Precision@5", "Precision@10", "NDCG@5", "NDCG@10"]

for metric in metrics:
    best[metric] = max(all_Ab_study_eval_results.items(), key=lambda x: x[1][metric])
    worst[metric] = min(all_Ab_study_eval_results.items(), key=lambda x: x[1][metric])

# %%
for metric, (study_id, data) in best.items():
    # print(f"Best {metric}: {all_Ab_study_eval_results[metric]:.4f} (Study {study_id}, n={data['n_history']}, T={data['T_max']})")
    print(f"Best {metric}: {data[metric]:.4f} (Study {study_id}, n={data['n_history']}, T={data['T_max']})")

print("\n")

seen_ids = []
for _, (study_id, data) in best.items():
    if study_id not in seen_ids:
        print(f"Ablation Study {study_id}")
        for key in list(data.keys()):
            value = data[key]
            if isinstance(value, np.float64):
                value = round(value, 4)
            print(f"{key}: {value}")
        print("\n")
        seen_ids.append(study_id)
# Out:
# Best Precision@5: 0.6898 (Study 17, n=10, T=10)
# Best Precision@10: 0.6129 (Study 17, n=10, T=10)
# Best NDCG@5: 0.7333 (Study 1, n=1, T=10)
# Best NDCG@10: 0.7616 (Study 1, n=1, T=10)
#
#
# Ablation Study 17
# n_history: 10
# T_max: 10
# Precision@5: 0.6898
# NDCG@5: 0.7238
# Precision@10: 0.6129
# NDCG@10: 0.7524
#
#
# Ablation Study 1
# n_history: 1
# T_max: 10
# Precision@5: 0.6882
# NDCG@5: 0.7333
# Precision@10: 0.6073
# NDCG@10: 0.7616

# %%
for metric, (study_id, data) in worst.items():
    print(f"Worst {metric}: {data[metric]:.4f} (Study {study_id}, n={data['n_history']}, T={data['T_max']})")

print("\n")

seen_ids = []
for _, (study_id, data) in worst.items():
    if study_id not in seen_ids:
        print(f"Ablation Study {study_id}")
        for key in list(data.keys()):
            value = data[key]
            if isinstance(value, np.float64):
                value = round(value, 4)
            print(f"{key}: {value}")
        print("\n")
        seen_ids.append(study_id)
# Out:
# Worst Precision@5: 0.6645 (Study 7, n=3, T=100)
# Worst Precision@10: 0.5929 (Study 7, n=3, T=100)
# Worst NDCG@5: 0.7029 (Study 7, n=3, T=100)
# Worst NDCG@10: 0.7381 (Study 7, n=3, T=100)
#
#
# Ablation Study 7
# n_history: 3
# T_max: 100
# Precision@5: 0.6645
# NDCG@5: 0.7029
# Precision@10: 0.5929
# NDCG@10: 0.7381
