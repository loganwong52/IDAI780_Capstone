# %%
import os
# import numpy as np
# import pandas as pd
# import random
# import pickle
import time
import port_for
import subprocess

# %%
# Load tensorboard
port = port_for.get_port(None)
print(f"Starting TensorBoard on port: {port}")

# Kill existing tensorboard
subprocess.run(["pkill", "-f", "tensorboard"])

# Start tensorboard
subprocess.Popen(["tensorboard", "--logdir", "../results/", "--port", f"{port}", "--host", "0.0.0.0"])

# Wait a moment
time.sleep(3)

# Test connection
import requests
try:
    r = requests.get(f"http://localhost:{port}")
    print(f"ssh -L {port}:localhost:{port} -N law3082@narnia.gccis.rit.edu")
    print(f"TensorBoard is running! Status: {r.status_code}")
    print(f"http://localhost:{port}")
except:
    print("TensorBoard failed to start")
# Out:
# Starting TensorBoard on port: 17352
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 12
#       9 subprocess.Popen(["tensorboard", "--logdir", "../results/", "--port", f"{port}", "--host", "0.0.0.0"])
#      11 # Wait a moment
# ---> 12 time.sleep(3)
#      14 # Test connection
#      15 import requests
#
# NameError: name 'time' is not defined
